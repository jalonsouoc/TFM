# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de Fuerteventura

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.legend()
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, indices, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    color_isla = 'tan'
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)
    
    return modelo
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_Fuerteventura = datos[datos['isla'] == 'FUERTEVENTURA']

datos_Fuerteventura = datos_Fuerteventura.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'Fuerteventura'         # Isla a la que se está realziando el estudio
fechas = datos_Fuerteventura.tail(dias_prediccion).index # Fechas de los días a predecir


variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                          # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_Fuerteventura_uni = datos_Fuerteventura[objetivo]
datos_Fuerteventura_uni_arr = np.array(datos_Fuerteventura_uni).reshape(-1, 1)

datos_Fuerteventura_mult_covid = datos_Fuerteventura[variables_covid]
datos_Fuerteventura_mult_atm = datos_Fuerteventura[variables_atm]
datos_Fuerteventura_mult_total = datos_Fuerteventura[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_uni_scaled = scaler.fit_transform(datos_Fuerteventura_uni_arr)

# %%
n_train = len(datos_Fuerteventura_uni_scaled) - dias_prediccion


train = datos_Fuerteventura_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_Fuerteventura_uni_scaled[n_train - dias_prediccion:len(datos_Fuerteventura_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 5s 41ms/step - loss: 0.0411 - val_loss: 0.0134
# Epoch 2/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0362 - val_loss: 0.0122
# Epoch 3/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0339 - val_loss: 0.0115
# Epoch 4/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0310 - val_loss: 0.0108
# Epoch 5/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0282 - val_loss: 0.0096
# Epoch 6/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0238 - val_loss: 0.0095
# Epoch 7/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0188 - val_loss: 0.0084
# Epoch 8/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0161 - val_loss: 0.0094
# Epoch 9/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0079
# Epoch 10/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0072
# Epoch 11/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0146 - val_loss: 0.0064
# Epoch 12/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0142 - val_loss: 0.0063
# Epoch 13/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0137 - val_loss: 0.0056
# Epoch 14/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0051
# Epoch 15/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0126 - val_loss: 0.0047
# Epoch 16/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0123 - val_loss: 0.0044
# Epoch 17/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0109 - val_loss: 0.0049
# Epoch 18/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0122 - val_loss: 0.0064
# Epoch 19/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0109 - val_loss: 0.0043
# Epoch 20/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0047
# Epoch 21/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0125 - val_loss: 0.0033
# Epoch 22/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0034
# Epoch 23/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0032
# Epoch 24/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0110 - val_loss: 0.0029
# Epoch 25/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0029
# Epoch 26/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0097 - val_loss: 0.0045
# Epoch 27/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0028
# Epoch 28/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0112 - val_loss: 0.0024
# Epoch 29/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0024
# Epoch 30/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0023
# Epoch 31/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0023
# Epoch 32/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0024
# Epoch 33/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0025
# Epoch 34/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0105 - val_loss: 0.0022
# Epoch 35/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0021
# Epoch 36/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0023
# Epoch 37/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0020
# Epoch 38/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0100 - val_loss: 0.0048
# Epoch 39/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0019
# Epoch 40/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0088 - val_loss: 0.0037
# Epoch 41/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0093 - val_loss: 0.0020
# Epoch 42/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0094 - val_loss: 0.0037
# Epoch 43/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0096 - val_loss: 0.0018
# Epoch 44/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0084 - val_loss: 0.0018
# Epoch 45/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0089 - val_loss: 0.0035
# Epoch 46/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0034
# Epoch 47/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0019
# Epoch 48/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0083 - val_loss: 0.0018
# Epoch 49/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0085 - val_loss: 0.0017
# Epoch 50/50
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0079 - val_loss: 0.0017

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 333ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 22, número de casos predichos 17.890911
# 2022-03-20: número de casos reales 21, número de casos predichos 19.469261
# 2022-03-21: número de casos reales 28, número de casos predichos 18.92987
# 2022-03-22: número de casos reales 33, número de casos predichos 17.192715
# 2022-03-23: número de casos reales 27, número de casos predichos 17.542479
# 2022-03-24: número de casos reales 28, número de casos predichos 20.537321
# 2022-03-25: número de casos reales 32, número de casos predichos 21.31756
# 2022-03-26: número de casos reales 12, número de casos predichos 20.227121
# 2022-03-27: número de casos reales 6, número de casos predichos 20.2276
# 2022-03-28: número de casos reales 22, número de casos predichos 18.537252

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_Fuerteventura_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 92.77824651039735
# Error absoluto medio (MAE) del modelo: 8.603735160827636
# Raíz del error cuadrático medio (RMSE) del modelo: 9.632146516244308

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_covid_scaled = scaler.fit_transform(datos_Fuerteventura_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_Fuerteventura_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_Fuerteventura_mult_covid_scaled) - dias_prediccion


train = datos_Fuerteventura_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_Fuerteventura_mult_covid_scaled[n_train - dias_prediccion:len(datos_Fuerteventura_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 3s 37ms/step - loss: 0.0474 - val_loss: 0.0205
# Epoch 2/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0416 - val_loss: 0.0189
# Epoch 3/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0376 - val_loss: 0.0171
# Epoch 4/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0333 - val_loss: 0.0160
# Epoch 5/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0271 - val_loss: 0.0152
# Epoch 6/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0239 - val_loss: 0.0157
# Epoch 7/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0225 - val_loss: 0.0148
# Epoch 8/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0205 - val_loss: 0.0121
# Epoch 9/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0191 - val_loss: 0.0129
# Epoch 10/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0185 - val_loss: 0.0117
# Epoch 11/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0166 - val_loss: 0.0103
# Epoch 12/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0157 - val_loss: 0.0101
# Epoch 13/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0146 - val_loss: 0.0091
# Epoch 14/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0086
# Epoch 15/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0127 - val_loss: 0.0068
# Epoch 16/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0117 - val_loss: 0.0077
# Epoch 17/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0128 - val_loss: 0.0073
# Epoch 18/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0067
# Epoch 19/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0061
# Epoch 20/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0115 - val_loss: 0.0055
# Epoch 21/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0104 - val_loss: 0.0052
# Epoch 22/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 0.0053
# Epoch 23/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0047
# Epoch 24/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0100 - val_loss: 0.0048
# Epoch 25/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0041
# Epoch 26/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0043
# Epoch 27/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0078 - val_loss: 0.0041
# Epoch 28/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0041
# Epoch 29/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0039
# Epoch 30/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0030
# Epoch 31/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0071 - val_loss: 0.0039
# Epoch 32/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0074 - val_loss: 0.0033
# Epoch 33/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0036
# Epoch 34/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0031
# Epoch 35/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0076 - val_loss: 0.0033
# Epoch 36/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0068 - val_loss: 0.0033
# Epoch 37/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0029
# Epoch 38/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0065 - val_loss: 0.0033
# Epoch 39/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0030
# Epoch 40/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0069 - val_loss: 0.0030
# Epoch 41/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0030
# Epoch 42/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0067 - val_loss: 0.0031
# Epoch 43/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 44/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0059 - val_loss: 0.0031
# Epoch 45/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0069 - val_loss: 0.0028
# Epoch 46/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0057 - val_loss: 0.0030
# Epoch 47/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0029
# Epoch 48/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0030
# Epoch 49/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0054 - val_loss: 0.0027
# Epoch 50/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0055 - val_loss: 0.0030

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 306ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 22, número de casos predichos 9.615273
# 2022-03-20: número de casos reales 21, número de casos predichos 9.869047
# 2022-03-21: número de casos reales 28, número de casos predichos 9.826743
# 2022-03-22: número de casos reales 33, número de casos predichos 9.767556
# 2022-03-23: número de casos reales 27, número de casos predichos 9.65618
# 2022-03-24: número de casos reales 28, número de casos predichos 9.729072
# 2022-03-25: número de casos reales 32, número de casos predichos 9.879621
# 2022-03-26: número de casos reales 12, número de casos predichos 9.698736
# 2022-03-27: número de casos reales 6, número de casos predichos 9.795296
# 2022-03-28: número de casos reales 22, número de casos predichos 9.742943

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_Fuerteventura_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 251.60632688734387
# Error absoluto medio (MAE) del modelo: 14.301012420654297
# Raíz del error cuadrático medio (RMSE) del modelo: 15.862103482430818

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_atm_scaled = scaler.fit_transform(datos_Fuerteventura_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_Fuerteventura_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_Fuerteventura_mult_atm_scaled) - dias_prediccion


train = datos_Fuerteventura_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_Fuerteventura_mult_atm_scaled[n_train - dias_prediccion:len(datos_Fuerteventura_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 3s 38ms/step - loss: 0.0431 - val_loss: 0.0187
# Epoch 2/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0388 - val_loss: 0.0201
# Epoch 3/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0335 - val_loss: 0.0169
# Epoch 4/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0266 - val_loss: 0.0150
# Epoch 5/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0239 - val_loss: 0.0184
# Epoch 6/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0216 - val_loss: 0.0166
# Epoch 7/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0207 - val_loss: 0.0134
# Epoch 8/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0199 - val_loss: 0.0113
# Epoch 9/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0190 - val_loss: 0.0107
# Epoch 10/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0179 - val_loss: 0.0115
# Epoch 11/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0170 - val_loss: 0.0136
# Epoch 12/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0168 - val_loss: 0.0091
# Epoch 13/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0164 - val_loss: 0.0086
# Epoch 14/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0140 - val_loss: 0.0075
# Epoch 15/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0136 - val_loss: 0.0069
# Epoch 16/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0140 - val_loss: 0.0062
# Epoch 17/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0063
# Epoch 18/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0124 - val_loss: 0.0059
# Epoch 19/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 0.0050
# Epoch 20/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0118 - val_loss: 0.0048
# Epoch 21/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 0.0044
# Epoch 22/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0111 - val_loss: 0.0042
# Epoch 23/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0119 - val_loss: 0.0047
# Epoch 24/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0036
# Epoch 25/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0034
# Epoch 26/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0111 - val_loss: 0.0038
# Epoch 27/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0034
# Epoch 28/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0082 - val_loss: 0.0038
# Epoch 29/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0030
# Epoch 30/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0042
# Epoch 31/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 0.0026
# Epoch 32/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 0.0026
# Epoch 33/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 0.0024
# Epoch 34/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0034
# Epoch 35/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 36/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0022
# Epoch 37/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 0.0023
# Epoch 38/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0021
# Epoch 39/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0039
# Epoch 40/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 41/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0019
# Epoch 42/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0027
# Epoch 43/50
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 44/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0019
# Epoch 45/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 46/50
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0077 - val_loss: 0.0018
# Epoch 47/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 48/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 0.0020
# Epoch 49/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0020
# Epoch 50/50
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0018

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 326ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 22, número de casos predichos 23.947834
# 2022-03-20: número de casos reales 21, número de casos predichos 24.82299
# 2022-03-21: número de casos reales 28, número de casos predichos 24.475653
# 2022-03-22: número de casos reales 33, número de casos predichos 24.068668
# 2022-03-23: número de casos reales 27, número de casos predichos 25.168753
# 2022-03-24: número de casos reales 28, número de casos predichos 28.210762
# 2022-03-25: número de casos reales 32, número de casos predichos 29.873882
# 2022-03-26: número de casos reales 12, número de casos predichos 28.80576
# 2022-03-27: número de casos reales 6, número de casos predichos 28.726763
# 2022-03-28: número de casos reales 22, número de casos predichos 27.341568

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_Fuerteventura_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 95.461610097218
# Error absoluto medio (MAE) del modelo: 6.884719657897949
# Raíz del error cuadrático medio (RMSE) del modelo: 9.770445747109903

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_total_scaled = scaler.fit_transform(datos_Fuerteventura_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_Fuerteventura_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_Fuerteventura_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_Fuerteventura_mult_total_scaled) - dias_prediccion


train = datos_Fuerteventura_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_Fuerteventura_mult_total_scaled[n_train - dias_prediccion:len(datos_Fuerteventura_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 [==============================] - 3s 41ms/step - loss: 0.0348 - val_loss: 0.0108
# Epoch 2/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0292 - val_loss: 0.0098
# Epoch 3/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0090
# Epoch 4/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0200 - val_loss: 0.0086
# Epoch 5/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0172 - val_loss: 0.0076
# Epoch 6/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0144 - val_loss: 0.0095
# Epoch 7/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0160 - val_loss: 0.0079
# Epoch 8/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0138 - val_loss: 0.0066
# Epoch 9/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0068
# Epoch 10/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0130 - val_loss: 0.0054
# Epoch 11/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0113 - val_loss: 0.0061
# Epoch 12/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.0052
# Epoch 13/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0066
# Epoch 14/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0101 - val_loss: 0.0054
# Epoch 15/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0102 - val_loss: 0.0051
# Epoch 16/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.0039
# Epoch 17/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0105 - val_loss: 0.0045
# Epoch 18/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0045
# Epoch 19/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0046
# Epoch 20/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0088 - val_loss: 0.0046
# Epoch 21/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0039
# Epoch 22/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 23/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0090 - val_loss: 0.0033
# Epoch 24/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0032
# Epoch 25/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0039
# Epoch 26/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0030
# Epoch 27/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0036
# Epoch 28/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0032
# Epoch 29/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0033
# Epoch 30/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0032
# Epoch 31/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0035
# Epoch 32/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0025
# Epoch 33/50
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0032
# Epoch 34/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.0029
# Epoch 35/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0027
# Epoch 36/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0030
# Epoch 37/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 38/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 39/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0025
# Epoch 40/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0030
# Epoch 41/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0021
# Epoch 42/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0026
# Epoch 43/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0020
# Epoch 44/50
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0027
# Epoch 45/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0029
# Epoch 46/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0028
# Epoch 47/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 48/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0025
# Epoch 49/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0026
# Epoch 50/50
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0025

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 374ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 22, número de casos predichos 11.321639
# 2022-03-20: número de casos reales 21, número de casos predichos 11.94361
# 2022-03-21: número de casos reales 28, número de casos predichos 11.701468
# 2022-03-22: número de casos reales 33, número de casos predichos 11.506115
# 2022-03-23: número de casos reales 27, número de casos predichos 11.26897
# 2022-03-24: número de casos reales 28, número de casos predichos 12.4267435
# 2022-03-25: número de casos reales 32, número de casos predichos 12.613336
# 2022-03-26: número de casos reales 12, número de casos predichos 11.429884
# 2022-03-27: número de casos reales 6, número de casos predichos 11.621825
# 2022-03-28: número de casos reales 22, número de casos predichos 11.441194

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_Fuerteventura_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 199.86711265243247
# Error absoluto medio (MAE) del modelo: 12.69688663482666
# Raíz del error cuadrático medio (RMSE) del modelo: 14.137436565814626
