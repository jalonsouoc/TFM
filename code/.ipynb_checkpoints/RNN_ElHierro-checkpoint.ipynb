# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de El Hierro

# %% [markdown]
# En este estudio se analiza la evolución de la pandemia de COVID-19 en la isla de El Hierro y la influencia de factores como los atmosféricas en la evolución de dicha enfermedad. Para este fin se utiliza el modelo de red neuronal recurrente mediante LSTM (Long Short-Term Memory) tanto univariable como multivariable.
#
# El estudio se fragmenta en 4 partes:
# * modelado univariable donde se emplea únicamente la variable objetivo.
# * modelado multivariable empleando las variables pandémicas. Dichas variables son:
#     * pcr_total: Número total de pruebas PCR realizadas.
#     * Urg_cv: Ingresos en el servicio de urgencias por COVID19.
#     * HPT_cv19: Ocupación del resto de camas para pacientes COVID.
#     * CCR_cv19: Ocupación de las unidades críticas con respirador para pacientes COVID.
# * modelado multivariable empleando las variables atmosféricas:
#     * tmin: Temperatura mínima diaria.
#     * tmed: Temperatura media diaria.
#     * presMax: Presión máxima al nivel de la estación.
# * modelado multivariable con todas las variables.

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    #plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.legend()
    plt.show()
    
def visualizar_historico(train, y_test, y_pred, variable, dias_historico, indices, tit, color, dif):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    plt.bar(indices, dif, width=0.5, color='black', alpha=0.2, align='edge', label='Diferencia')
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=70)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    historico = modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=32, verbose=2)
    
    return modelo, historico
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))
        
def visualizar_perdida(historico):
    plt.plot(historico.history['loss'], label='train')
    plt.plot(historico.history['val_loss'], label='test')
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.title('Pérdida del modelo')
    plt.legend()
    plt.show()

# %% [markdown]
# Inicialmente cargamos los datos del fichero con los datos procesados anteriormente y obtenemos los datos únicamente para la isla de El Hierro.

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_ElHierro = datos[datos['isla'] == 'EL HIERRO']

datos_ElHierro = datos_ElHierro.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'El Hierro'         # Isla a la que se está realziando el estudio
fechas = datos_ElHierro.tail(dias_prediccion).index # Fechas de los días a predecir
color_isla = 'purple' # Color de la isla en las visualizaciones
n_dias_train_vis = 100    # Número de días del conjunto de train a visualizar en el conjunto de train

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %% [markdown]
# Separamos los datos en función de las variables a emplear en cada uno de los estudios que se van a realizar.

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_ElHierro_uni = datos_ElHierro[objetivo]
datos_ElHierro_uni_arr = np.array(datos_ElHierro_uni).reshape(-1, 1)

datos_ElHierro_mult_covid = datos_ElHierro[variables_covid]
datos_ElHierro_mult_atm = datos_ElHierro[variables_atm]
datos_ElHierro_mult_total = datos_ElHierro[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %% [markdown]
# Realizamos el análisis con los datos únicamente de la variable objetivo obteniendo un modelo de reuronal recurrente univariable.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_uni_scaled = scaler.fit_transform(datos_ElHierro_uni_arr)

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_ElHierro_uni_scaled) - dias_prediccion


train = datos_ElHierro_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_ElHierro_uni_scaled[n_train - dias_prediccion:len(datos_ElHierro_uni_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0476 - val_loss: 0.0308 - 3s/epoch - 215ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0438 - val_loss: 0.0284 - 122ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0415 - val_loss: 0.0268 - 120ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0400 - val_loss: 0.0250 - 119ms/epoch - 8ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0372 - val_loss: 0.0229 - 121ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0354 - val_loss: 0.0225 - 120ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0324 - val_loss: 0.0202 - 121ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0301 - val_loss: 0.0191 - 122ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0263 - val_loss: 0.0177 - 120ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0241 - val_loss: 0.0175 - 120ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0232 - val_loss: 0.0163 - 120ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0208 - val_loss: 0.0155 - 119ms/epoch - 8ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0181 - 121ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0194 - val_loss: 0.0145 - 119ms/epoch - 8ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0133 - 119ms/epoch - 8ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0178 - val_loss: 0.0136 - 119ms/epoch - 8ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0184 - val_loss: 0.0137 - 120ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0174 - val_loss: 0.0117 - 120ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0166 - val_loss: 0.0113 - 119ms/epoch - 8ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0175 - val_loss: 0.0109 - 122ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.0115 - 119ms/epoch - 8ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0156 - val_loss: 0.0102 - 121ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0168 - val_loss: 0.0119 - 118ms/epoch - 8ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0100 - 119ms/epoch - 8ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0152 - val_loss: 0.0096 - 120ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0113 - 124ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0096 - 121ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0102 - 124ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0148 - val_loss: 0.0140 - 123ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0091 - 122ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0147 - val_loss: 0.0086 - 123ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0096 - 122ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0136 - val_loss: 0.0087 - 121ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0084 - 123ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0136 - val_loss: 0.0091 - 122ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0093 - 120ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0137 - 122ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0088 - 120ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0094 - 123ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0098 - 123ms/epoch - 9ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 320ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 8, número de casos predichos 13.256989
# 2022-03-20: número de casos reales 2, número de casos predichos 11.830075
# 2022-03-21: número de casos reales 11, número de casos predichos 10.705375
# 2022-03-22: número de casos reales 12, número de casos predichos 8.5391
# 2022-03-23: número de casos reales 17, número de casos predichos 9.357972
# 2022-03-24: número de casos reales 4, número de casos predichos 9.486424
# 2022-03-25: número de casos reales 10, número de casos predichos 8.857289
# 2022-03-26: número de casos reales 1, número de casos predichos 8.16904
# 2022-03-27: número de casos reales 3, número de casos predichos 8.027499
# 2022-03-28: número de casos reales 4, número de casos predichos 8.361182

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-5.25698853, -9.83007526,  0.29462528,  3.46090031,  7.64202785,
#        -5.48642445,  1.14271069, -7.16903973, -5.0274992 , -4.36118221])

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_ElHierro_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Para la evaluación del modelo se utilizarán las siguientes estimadores:
# * MAE: Error absoluto medio
# * MSE: Error cuadrático medio
# * RMSE: Raíz del error cuadrático medio

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 32.18289627761415
# Error absoluto medio (MAE) del modelo: 4.967147350311279
# Raíz del error cuadrático medio (RMSE) del modelo: 5.672997115953272

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %% [markdown]
# Realizamos el análisis con los datos pandémicos obteniendo un modelo de red neuronal multivariable en base a dichas variables.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max. Dado que poseemos más de una variable también creamos un escalador univariable para poder desnormalizar los datos predichos en la fase final.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_covid_scaled = scaler.fit_transform(datos_ElHierro_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_ElHierro_mult_covid[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_ElHierro_mult_covid_scaled) - dias_prediccion


train = datos_ElHierro_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_ElHierro_mult_covid_scaled[n_train - dias_prediccion:len(datos_ElHierro_mult_covid_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0413 - val_loss: 0.0261 - 3s/epoch - 218ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0352 - val_loss: 0.0229 - 135ms/epoch - 10ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0297 - val_loss: 0.0229 - 132ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0275 - val_loss: 0.0204 - 135ms/epoch - 10ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0247 - val_loss: 0.0216 - 132ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0229 - val_loss: 0.0221 - 136ms/epoch - 10ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0219 - val_loss: 0.0194 - 133ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0223 - val_loss: 0.0177 - 136ms/epoch - 10ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0160 - 140ms/epoch - 10ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0158 - 135ms/epoch - 10ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0190 - val_loss: 0.0147 - 135ms/epoch - 10ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0181 - val_loss: 0.0145 - 133ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0170 - val_loss: 0.0147 - 133ms/epoch - 10ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0155 - val_loss: 0.0129 - 135ms/epoch - 10ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0125 - 136ms/epoch - 10ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.0129 - 129ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.0116 - 130ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0115 - 131ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0157 - val_loss: 0.0114 - 131ms/epoch - 9ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.0134 - 131ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.0105 - 130ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0106 - 131ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0103 - 132ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0097 - 131ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0096 - 132ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0096 - 130ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0107 - 132ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0105 - 136ms/epoch - 10ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0091 - 135ms/epoch - 10ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0089 - 132ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0091 - 132ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0087 - 133ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0116 - 133ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0085 - 131ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0099 - 137ms/epoch - 10ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0091 - 135ms/epoch - 10ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0083 - 136ms/epoch - 10ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0101 - val_loss: 0.0084 - 130ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0099 - 131ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0089 - 130ms/epoch - 9ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 305ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 8, número de casos predichos 13.138538
# 2022-03-20: número de casos reales 2, número de casos predichos 11.313462
# 2022-03-21: número de casos reales 11, número de casos predichos 9.741335
# 2022-03-22: número de casos reales 12, número de casos predichos 7.4700427
# 2022-03-23: número de casos reales 17, número de casos predichos 8.36081
# 2022-03-24: número de casos reales 4, número de casos predichos 8.665239
# 2022-03-25: número de casos reales 10, número de casos predichos 7.1372013
# 2022-03-26: número de casos reales 1, número de casos predichos 6.266938
# 2022-03-27: número de casos reales 3, número de casos predichos 6.17994
# 2022-03-28: número de casos reales 4, número de casos predichos 6.465199

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-5.13853836, -9.31346226,  1.25866508,  4.52995729,  8.63918972,
#        -4.66523933,  2.86279869, -5.26693821, -3.17994022, -2.46519899])

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_ElHierro_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 28.377544400560918
# Error absoluto medio (MAE) del modelo: 4.7319928169250485
# Raíz del error cuadrático medio (RMSE) del modelo: 5.327057762082266

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %% [markdown]
# Realizamos el análisis con los datos atmosféricos obteniendo un modelo de red neuronal multivariable en base a dichas variables.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max. Dado que poseemos más de una variable también creamos un escalador univariable para poder desnormalizar los datos predichos en la fase final.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_atm_scaled = scaler.fit_transform(datos_ElHierro_mult_atm)

# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_ElHierro_mult_atm[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_ElHierro_mult_atm_scaled) - dias_prediccion


train = datos_ElHierro_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_ElHierro_mult_atm_scaled[n_train - dias_prediccion:len(datos_ElHierro_mult_atm_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0521 - val_loss: 0.0355 - 3s/epoch - 219ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0449 - val_loss: 0.0348 - 126ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0415 - val_loss: 0.0305 - 127ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0369 - val_loss: 0.0286 - 129ms/epoch - 9ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0350 - val_loss: 0.0278 - 127ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0324 - val_loss: 0.0275 - 130ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0311 - val_loss: 0.0246 - 130ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0294 - val_loss: 0.0261 - 128ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0264 - val_loss: 0.0223 - 125ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0264 - val_loss: 0.0204 - 127ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0250 - val_loss: 0.0192 - 127ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0241 - val_loss: 0.0186 - 128ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0223 - val_loss: 0.0259 - 130ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0222 - val_loss: 0.0170 - 131ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0205 - val_loss: 0.0164 - 128ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0205 - val_loss: 0.0155 - 129ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0183 - val_loss: 0.0147 - 131ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0183 - val_loss: 0.0144 - 137ms/epoch - 10ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.0131 - 130ms/epoch - 9ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.0290 - 132ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0117 - 129ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0160 - val_loss: 0.0121 - 133ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0115 - 126ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0105 - 129ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0144 - val_loss: 0.0141 - 129ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0100 - 127ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0144 - val_loss: 0.0132 - 128ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0098 - 126ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0096 - 127ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.0111 - 130ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0108 - 129ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0098 - 129ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0088 - 127ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0091 - 126ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0144 - 126ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0097 - 128ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0133 - 129ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0148 - 129ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0085 - 128ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0108 - 130ms/epoch - 9ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 292ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 8, número de casos predichos 13.287674
# 2022-03-20: número de casos reales 2, número de casos predichos 11.692234
# 2022-03-21: número de casos reales 11, número de casos predichos 10.433471
# 2022-03-22: número de casos reales 12, número de casos predichos 8.946312
# 2022-03-23: número de casos reales 17, número de casos predichos 9.475666
# 2022-03-24: número de casos reales 4, número de casos predichos 9.48723
# 2022-03-25: número de casos reales 10, número de casos predichos 9.364558
# 2022-03-26: número de casos reales 1, número de casos predichos 9.165002
# 2022-03-27: número de casos reales 3, número de casos predichos 9.196699
# 2022-03-28: número de casos reales 4, número de casos predichos 9.37662

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-5.28767395, -9.69223404,  0.56652927,  3.05368805,  7.52433395,
#        -5.4872303 ,  0.63544178, -8.16500187, -6.19669914, -5.37662029])

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_ElHierro_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 35.26483282349618
# Error absoluto medio (MAE) del modelo: 5.198545265197754
# Raíz del error cuadrático medio (RMSE) del modelo: 5.938420061219666

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %% [markdown]
# Realizamos el análisis unificando los datos tanto pandémicos como atmosféricos.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max. Dado que poseemos más de una variable también creamos un escalador univariable para poder desnormalizar los datos predichos en la fase final.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_total_scaled = scaler.fit_transform(datos_ElHierro_mult_total)

# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_ElHierro_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_ElHierro_mult_total[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_ElHierro_mult_total_scaled) - dias_prediccion


train = datos_ElHierro_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_ElHierro_mult_total_scaled[n_train - dias_prediccion:len(datos_ElHierro_mult_total_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0411 - val_loss: 0.0244 - 3s/epoch - 222ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0370 - val_loss: 0.0217 - 163ms/epoch - 12ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0328 - val_loss: 0.0200 - 156ms/epoch - 11ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0293 - val_loss: 0.0206 - 156ms/epoch - 11ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0271 - val_loss: 0.0185 - 154ms/epoch - 11ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0246 - val_loss: 0.0171 - 156ms/epoch - 11ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0217 - val_loss: 0.0194 - 159ms/epoch - 11ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0218 - val_loss: 0.0204 - 160ms/epoch - 11ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0202 - val_loss: 0.0345 - 159ms/epoch - 11ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0142 - 160ms/epoch - 11ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0184 - val_loss: 0.0174 - 158ms/epoch - 11ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0188 - val_loss: 0.0129 - 162ms/epoch - 12ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0170 - val_loss: 0.0204 - 162ms/epoch - 12ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0166 - val_loss: 0.0122 - 162ms/epoch - 12ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.0144 - 157ms/epoch - 11ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0160 - val_loss: 0.0112 - 161ms/epoch - 11ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0105 - 154ms/epoch - 11ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0113 - 153ms/epoch - 11ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0101 - 154ms/epoch - 11ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0113 - 156ms/epoch - 11ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0098 - 155ms/epoch - 11ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0091 - 154ms/epoch - 11ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0110 - 157ms/epoch - 11ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0094 - 155ms/epoch - 11ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0140 - val_loss: 0.0084 - 155ms/epoch - 11ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0130 - 154ms/epoch - 11ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0085 - 155ms/epoch - 11ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0118 - 157ms/epoch - 11ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0126 - val_loss: 0.0099 - 156ms/epoch - 11ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0081 - 154ms/epoch - 11ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0084 - 154ms/epoch - 11ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0081 - 157ms/epoch - 11ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0081 - 155ms/epoch - 11ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0081 - 155ms/epoch - 11ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0080 - 155ms/epoch - 11ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0099 - 155ms/epoch - 11ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0144 - 154ms/epoch - 11ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0078 - 154ms/epoch - 11ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0099 - 153ms/epoch - 11ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0117 - 154ms/epoch - 11ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 297ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 8, número de casos predichos 15.450279
# 2022-03-20: número de casos reales 2, número de casos predichos 13.783158
# 2022-03-21: número de casos reales 11, número de casos predichos 12.196147
# 2022-03-22: número de casos reales 12, número de casos predichos 10.100244
# 2022-03-23: número de casos reales 17, número de casos predichos 10.952382
# 2022-03-24: número de casos reales 4, número de casos predichos 11.23254
# 2022-03-25: número de casos reales 10, número de casos predichos 9.679675
# 2022-03-26: número de casos reales 1, número de casos predichos 8.714569
# 2022-03-27: número de casos reales 3, número de casos predichos 8.426717
# 2022-03-28: número de casos reales 4, número de casos predichos 8.588924

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([ -7.45027924, -11.7831583 ,  -1.19614697,   1.89975643,
#          6.04761791,  -7.23254013,   0.3203249 ,  -7.71456909,
#         -5.4267168 ,  -4.58892441])

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_ElHierro_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 39.839730829501605
# Error absoluto medio (MAE) del modelo: 5.36600341796875
# Raíz del error cuadrático medio (RMSE) del modelo: 6.31187221270374
