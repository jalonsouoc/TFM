# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo ARIMA para la isla de Gran Canaria

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def estudio_STL(df):
    stl = STL(df, period=12)
    res = stl.fit()
    
    fig = res.plot()

    
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator(interval=1))

    plt.xticks(rotation=90)
    plt.show()
    

def visualizar_adf(df):
    ''' Visualiza el p-valor del estudio de Dickey-Fuller
    
    Args:
        df (DataFrame): DataFrame con los datos a realizar el estudio (DataFrame con una única columna que es la objetivo)
    '''

    adf = adfuller(df)
    print("ADF p-value:" + str(adf[1]))
    

def visualizar_acf(df, n_lags):
    plt.figure(figsize=(16, 10))
    plot_acf(df, lags=n_lags)
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelación')
    plt.title('ACF')
    plt.show()
    
def visualizar_pacf(df, n_lags):
    plt.figure(figsize=(16, 6))
    plot_pacf(df, lags=n_lags)
    plt.xlabel('Lag')
    plt.ylabel('Autocorrelación parcial')
    plt.title('PACF')
    plt.show()
    
    
def visualizar_dif_pred_test(test, pred, variable, tit):
    plt.figure(figsize=(10, 6))

    if variable != '':
        plt.plot(test.index, test[variable], label='Test', color='green')
    else:
        plt.plot(test.index, test, label='Test', color='green')
    plt.plot(test.index, pred, label='Predicción', color='orange')


    plt.xticks(rotation=60)
    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))

    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color='gray')
        plt.plot(test.index, test[variable], label='Test', color='green')
    else:
        plt.plot(train_s.index, train_s, label='Train', color='gray')
        plt.plot(test.index, test, label='Test', color='green')
    
    plt.plot(test.index, pred, label='Predicción', color='orange')
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(test.index), step=10),   train_s.index.union(test.index)[::10], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_bic_aic(modelo):
    ''' Visualiza los datos de BIC (Criterio de Información Bayesiano) y  AIC (Criterio de Información de Akaike)
    
    Args:
        modelo (ARIMA): modelo ARIMA entrenado
    '''
    
    bic = modelo.bic
    aic = modelo.aic

    print("BIC del modelo ARIMA:", bic)
    print("AIC del modelo ARIMA:", aic)
    
def visualizar_resultados_texto(y_test, y_pred, variable):
    fechas = y_test.index
    for i in range(len(y_test)):
        if variable != '':
            valor_test = y_test[variable][i]
        else:
            valor_test = y_test[i] 
        print(str(fechas[i]) + ': número de casos reales ' + str(valor_test) + ', número de casos predichos ' + str(y_pred[i]))

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos_islas = pd.read_csv('../data/Final/datos_reduc_final.csv', header=0)

# %%
datos_GranCanaria = datos_islas[datos_islas['isla'] == 'GRAN CANARIA'].copy()

# Ordenamos por fecha por si los datos devueltos no estuvieran en orden
datos_GranCanaria = datos_GranCanaria.sort_values(by='fecha')

# Añadimos como índice de los datos la fecha
datos_GranCanaria.set_index('fecha', inplace=True)

# Variables 
variables_covid = ['pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']
variables_atm = ['tmin', 'tmed', 'presMax']
variables = ['pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax']

objetivo = 'numero_casos' # Variable objetivo
n_dias = 10               # Numero de días correspondiente al conjunto de TEST

# Obtenemos los conjuntos de datos para cada modelo con las variables necesarias para cada uno de ellos
# Modelo Univariable
datos_GranCanaria_arima_uni = datos_GranCanaria['numero_casos']
datos_GranCanaria_arima_mult_covid = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']]
datos_GranCanaria_arima_mult_atm = datos_GranCanaria[[objetivo, 'tmin', 'tmed', 'presMax']]
datos_GranCanaria_arima_total = datos_GranCanaria.copy()

# %%
estudio_STL(datos_GranCanaria_arima_uni)

# %%
visualizar_adf(datos_GranCanaria_arima_uni)
# Out:
# ADF p-value:0.05546091881926496

# %%
datos_GranCanaria_arima_uni_1d = datos_GranCanaria_arima_uni.diff().dropna()
visualizar_adf(datos_GranCanaria_arima_uni_1d)
# Out:
# ADF p-value:0.0001415224330060985

# %% [markdown]
# Para la isla de Gran Canaria es necesaria una diferenciación para poder obtener una serie temporal estacionaria por lo que el parámetro d es 1

# %%
visualizar_acf(datos_GranCanaria_arima_uni, 30)

# %%
visualizar_pacf(datos_GranCanaria_arima_uni, 10)

# %%
# Parámetros del modelo ARIMA
p = 2 
d = 1
q = 6

# %% [markdown]
# # Modelo ARIMA univariable

# %%
# Conjuntos de entrenamiento y test
train = datos_GranCanaria_arima_uni.iloc[:len(datos_GranCanaria_arima_uni) - n_dias]
test =  datos_GranCanaria_arima_uni.iloc[len(datos_GranCanaria_arima_uni) - n_dias:]

# %%
#order=(p,d,q)

arima_GranCanaria = ARIMA(endog=train, order=(p, d, q), freq = 'D')
modelo_arima_GranCanaria = arima_GranCanaria.fit()
# Out:
# D:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# D:\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
visualizar_bic_aic(modelo_arima_GranCanaria)
# Out:
# BIC del modelo ARIMA: 5519.376799211184
# AIC del modelo ARIMA: 5482.575395332163

# %%
pred = modelo_arima_GranCanaria.forecast(steps=10)
#pred = model_arima_GranCanaria.predict(start=test.index[0], end=test.index[-1])

# %%
visualizar_resultados_texto(test, pred, '')
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 714.6245364180766
# 2022-03-20: número de casos reales 461, número de casos predichos 726.8055382614539
# 2022-03-21: número de casos reales 948, número de casos predichos 764.4370660088936
# 2022-03-22: número de casos reales 966, número de casos predichos 880.2172190011337
# 2022-03-23: número de casos reales 948, número de casos predichos 843.6346452212365
# 2022-03-24: número de casos reales 790, número de casos predichos 982.3220875715824
# 2022-03-25: número de casos reales 741, número de casos predichos 1017.407030921419
# 2022-03-26: número de casos reales 428, número de casos predichos 946.3068355419565
# 2022-03-27: número de casos reales 368, número de casos predichos 919.4920023373592
# 2022-03-28: número de casos reales 528, número de casos predichos 954.9681173898132

# %%
# Título para las visualizaciones
isla = 'Gran Canaria'
tit = 'Modelo ARIMA univariable isla de ' + isla
visualizar_dif_pred_test(test, pred, '', tit)

# %%
visualizar_historico(train, test, pred, '', 140, tit)

# %%
mae, mse, rmse = obtener_errores(test, pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 102406.20297186357
# Error absoluto medio (MAE) del modelo: 278.6637218210397
# Raíz del error cuadrático medio (RMSE) del modelo: 320.0096919967637

# %%
visualizar_acf(modelo_arima_GranCanaria.resid, 30)

# %% [markdown]
# # Modelo ARIMA multivariable con variables de pandemia

# %%
train = datos_GranCanaria_arima_mult_covid.iloc[:len(datos_GranCanaria_arima_mult_covid) - n_dias]
test =  datos_GranCanaria_arima_mult_covid.iloc[len(datos_GranCanaria_arima_mult_covid) - n_dias:]

# %%
#order=(p,d,q)
# Parámetros del modelo ARIMA

arima_GranCanaria = ARIMA(endog=train[objetivo],exog=train[variables_covid], order=(p, d, q), freq = 'D')
modelo_arima_GranCanaria = arima_GranCanaria.fit()
# Out:
# D:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# D:\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
visualizar_bic_aic(modelo_arima_GranCanaria)
# Out:
# BIC del modelo ARIMA: 5218.015981367499
# AIC del modelo ARIMA: 5164.85839798669

# %%
pred = modelo_arima_GranCanaria.forecast(steps=10, exog=test[variables_covid])

# %%
visualizar_resultados_texto(test, pred, objetivo)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 646.1192730606986
# 2022-03-20: número de casos reales 461, número de casos predichos 557.3416333858441
# 2022-03-21: número de casos reales 948, número de casos predichos 829.7884854369481
# 2022-03-22: número de casos reales 966, número de casos predichos 902.6931823077977
# 2022-03-23: número de casos reales 948, número de casos predichos 888.9297110152343
# 2022-03-24: número de casos reales 790, número de casos predichos 857.0179251318158
# 2022-03-25: número de casos reales 741, número de casos predichos 865.7686556209446
# 2022-03-26: número de casos reales 428, número de casos predichos 685.0180276402514
# 2022-03-27: número de casos reales 368, número de casos predichos 633.6680553143352
# 2022-03-28: número de casos reales 528, número de casos predichos 775.5625601123163

# %%
tit = 'Modelo ARIMA multivariable con variables pandémicas para la isla de ' + isla
visualizar_dif_pred_test(test, pred, objetivo, tit)

# %%
visualizar_historico(train, test, pred, objetivo, 100, tit)

# %%
mae, mse, rmse = obtener_errores(test[objetivo], pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 26153.231767396286
# Error absoluto medio (MAE) del modelo: 141.2084751506226
# Raíz del error cuadrático medio (RMSE) del modelo: 161.7196084814587

# %% [markdown]
# # Modelo ARIMA multivariable con variables atmosféricas

# %%
train = datos_GranCanaria_arima_mult_atm.iloc[:len(datos_GranCanaria_arima_mult_atm) - n_dias]
test =  datos_GranCanaria_arima_mult_atm.iloc[len(datos_GranCanaria_arima_mult_atm) - n_dias:]

# %%
arima_GranCanaria = ARIMA(endog=train[objetivo],exog=train[variables_atm], order=(p, d, q), freq = 'D')
modelo_arima_GranCanaria = arima_GranCanaria.fit()
# Out:
# D:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# D:\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
visualizar_bic_aic(modelo_arima_GranCanaria)
# Out:
# BIC del modelo ARIMA: 5498.740895538633
# AIC del modelo ARIMA: 5449.672357033271

# %%
pred = modelo_arima_GranCanaria.forecast(steps=10, exog=test[variables_atm])

# %%
visualizar_resultados_texto(test, pred, objetivo)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 750.766285264976
# 2022-03-20: número de casos reales 461, número de casos predichos 789.0768472043592
# 2022-03-21: número de casos reales 948, número de casos predichos 887.5698602173966
# 2022-03-22: número de casos reales 966, número de casos predichos 981.4151197900028
# 2022-03-23: número de casos reales 948, número de casos predichos 981.7767804603786
# 2022-03-24: número de casos reales 790, número de casos predichos 1022.1337005252781
# 2022-03-25: número de casos reales 741, número de casos predichos 1059.9657238542472
# 2022-03-26: número de casos reales 428, número de casos predichos 1086.7865458052115
# 2022-03-27: número de casos reales 368, número de casos predichos 1096.3617735037078
# 2022-03-28: número de casos reales 528, número de casos predichos 1059.056761392625

# %%
tit = 'Modelo ARIMA multivariable con variables atmosféricas para la isla de ' + isla

visualizar_dif_pred_test(test, pred, objetivo, tit)

# %%
visualizar_historico(train, test, pred, objetivo, 100, tit)

# %%
mae, mse, rmse = obtener_errores(test[objetivo], pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 156224.39290498887
# Error absoluto medio (MAE) del modelo: 312.47696775833896
# Raíz del error cuadrático medio (RMSE) del modelo: 395.2523154960498

# %% [markdown]
# # Modelo ARIMA multivariable con todas las variables

# %%
train = datos_GranCanaria_arima_total.iloc[:len(datos_GranCanaria_arima_total) - n_dias]
test =  datos_GranCanaria_arima_total.iloc[len(datos_GranCanaria_arima_total) - n_dias:]

# %%
arima_GranCanaria = ARIMA(endog=train[objetivo],exog=train[variables], order=(p, d, q), freq = 'D')
modelo_arima_GranCanaria = arima_GranCanaria.fit()
# Out:
# D:\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# D:\anaconda3\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
visualizar_bic_aic(modelo_arima_GranCanaria)
# Out:
# BIC del modelo ARIMA: 5236.6855165200805
# AIC del modelo ARIMA: 5171.260798512931

# %%
pred = modelo_arima_GranCanaria.forecast(steps=10, exog=test[variables])

# %%
tit = 'Modelo ARIMA multivariable con todas las variables para la isla de ' + isla

visualizar_dif_pred_test(test, pred, objetivo, tit)

# %%
visualizar_historico(train, test, pred, objetivo, 100, tit)

# %%
mae, mse, rmse = obtener_errores(test[objetivo], pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 28325.90159734682
# Error absoluto medio (MAE) del modelo: 147.30650348725175
# Raíz del error cuadrático medio (RMSE) del modelo: 168.30300531287853
