# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de La Gomera

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    #plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.legend()
    plt.show()
    
def visualizar_historico(train, y_test, y_pred, variable, dias_historico, indices, tit, color, dif):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    plt.bar(indices, dif, width=0.5, color='black', alpha=0.2, align='edge', label='Diferencia')
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=70)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    historico = modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=32, verbose=2)
    
    return modelo, historico
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))
        
def visualizar_perdida(historico):
    plt.plot(historico.history['loss'], label='train')
    plt.plot(historico.history['val_loss'], label='test')
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.title('Pérdida del modelo')
    plt.legend()
    plt.show()

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_LaGomera = datos[datos['isla'] == 'LA GOMERA']

datos_LaGomera = datos_LaGomera.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'La Gomera'         # Isla a la que se está realziando el estudio
fechas = datos_LaGomera.tail(dias_prediccion).index # Fechas de los días a predecir
color_isla = 'olive' # Color de la isla en las visualizaciones
n_dias_train_vis = 100    # Número de días del conjunto de train a visualizar en el conjunto de train

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_LaGomera_uni = datos_LaGomera[objetivo]
datos_LaGomera_uni_arr = np.array(datos_LaGomera_uni).reshape(-1, 1)

datos_LaGomera_mult_covid = datos_LaGomera[variables_covid]
datos_LaGomera_mult_atm = datos_LaGomera[variables_atm]
datos_LaGomera_mult_total = datos_LaGomera[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_uni_scaled = scaler.fit_transform(datos_LaGomera_uni_arr)

# %%
n_train = len(datos_LaGomera_uni_scaled) - dias_prediccion


train = datos_LaGomera_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_uni_scaled[n_train - dias_prediccion:len(datos_LaGomera_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 - 5s - loss: 0.0504 - val_loss: 0.1888 - 5s/epoch - 327ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0441 - val_loss: 0.1682 - 128ms/epoch - 9ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0402 - val_loss: 0.1408 - 118ms/epoch - 8ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0353 - val_loss: 0.1051 - 121ms/epoch - 9ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0283 - val_loss: 0.0716 - 119ms/epoch - 8ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0262 - val_loss: 0.0685 - 118ms/epoch - 8ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0230 - val_loss: 0.0712 - 118ms/epoch - 8ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0242 - val_loss: 0.0672 - 119ms/epoch - 8ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0235 - val_loss: 0.0655 - 118ms/epoch - 8ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0205 - val_loss: 0.0651 - 117ms/epoch - 8ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0202 - val_loss: 0.0787 - 117ms/epoch - 8ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0726 - 119ms/epoch - 8ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0189 - val_loss: 0.0678 - 119ms/epoch - 8ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.0644 - 118ms/epoch - 8ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0180 - val_loss: 0.0643 - 118ms/epoch - 8ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0174 - val_loss: 0.0661 - 119ms/epoch - 8ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0182 - val_loss: 0.0609 - 119ms/epoch - 8ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0167 - val_loss: 0.0637 - 119ms/epoch - 8ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0620 - 120ms/epoch - 9ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.0596 - 119ms/epoch - 8ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0159 - val_loss: 0.0655 - 119ms/epoch - 8ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.0640 - 120ms/epoch - 9ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0152 - val_loss: 0.0604 - 117ms/epoch - 8ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0606 - 118ms/epoch - 8ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0147 - val_loss: 0.0627 - 118ms/epoch - 8ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0755 - 119ms/epoch - 8ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0149 - val_loss: 0.0605 - 118ms/epoch - 8ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0668 - 122ms/epoch - 9ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0641 - 119ms/epoch - 9ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0609 - 120ms/epoch - 9ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0621 - 119ms/epoch - 8ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0582 - 120ms/epoch - 9ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0635 - 119ms/epoch - 8ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0628 - 120ms/epoch - 9ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0584 - 119ms/epoch - 8ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0585 - 118ms/epoch - 8ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0576 - 117ms/epoch - 8ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0646 - 118ms/epoch - 8ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0107 - val_loss: 0.0576 - 119ms/epoch - 8ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0593 - 119ms/epoch - 9ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0579 - 118ms/epoch - 8ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0126 - val_loss: 0.0610 - 120ms/epoch - 9ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0582 - 118ms/epoch - 8ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0648 - 119ms/epoch - 8ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0576 - 119ms/epoch - 9ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0578 - 119ms/epoch - 8ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0657 - 118ms/epoch - 8ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0644 - 120ms/epoch - 9ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0579 - 119ms/epoch - 9ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0659 - 117ms/epoch - 8ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 318ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 29.32826
# 2022-03-20: número de casos reales 7, número de casos predichos 29.647602
# 2022-03-21: número de casos reales 53, número de casos predichos 28.849705
# 2022-03-22: número de casos reales 36, número de casos predichos 29.390255
# 2022-03-23: número de casos reales 32, número de casos predichos 30.156298
# 2022-03-24: número de casos reales 32, número de casos predichos 31.802608
# 2022-03-25: número de casos reales 27, número de casos predichos 29.376013
# 2022-03-26: número de casos reales 13, número de casos predichos 29.369265
# 2022-03-27: número de casos reales 14, número de casos predichos 27.757633
# 2022-03-28: número de casos reales 13, número de casos predichos 27.161388

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-17.32826042, -22.64760208,  24.15029526,   6.60974503,
#          1.84370232,   0.19739151,  -2.3760128 , -16.3692646 ,
#        -13.75763321, -14.1613884 ])

# %%
datos_train = datos_LaGomera_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 210.69618345721537
# Error absoluto medio (MAE) del modelo: 11.94412956237793
# Raíz del error cuadrático medio (RMSE) del modelo: 14.515377482422403

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_covid_scaled = scaler.fit_transform(datos_LaGomera_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_covid_scaled) - dias_prediccion


train = datos_LaGomera_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_covid_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 - 3s - loss: 0.0547 - val_loss: 0.2001 - 3s/epoch - 213ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0473 - val_loss: 0.1636 - 133ms/epoch - 9ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0405 - val_loss: 0.1233 - 129ms/epoch - 9ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0362 - val_loss: 0.0896 - 132ms/epoch - 9ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0321 - val_loss: 0.0790 - 129ms/epoch - 9ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0294 - val_loss: 0.0764 - 129ms/epoch - 9ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0263 - val_loss: 0.0753 - 129ms/epoch - 9ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0251 - val_loss: 0.0681 - 129ms/epoch - 9ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0257 - val_loss: 0.0677 - 129ms/epoch - 9ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0229 - val_loss: 0.0708 - 129ms/epoch - 9ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0227 - val_loss: 0.0715 - 128ms/epoch - 9ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0203 - val_loss: 0.0658 - 128ms/epoch - 9ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0201 - val_loss: 0.0694 - 130ms/epoch - 9ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0187 - val_loss: 0.0700 - 129ms/epoch - 9ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0646 - 129ms/epoch - 9ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0175 - val_loss: 0.0758 - 129ms/epoch - 9ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0175 - val_loss: 0.0787 - 128ms/epoch - 9ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0180 - val_loss: 0.0633 - 129ms/epoch - 9ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0157 - val_loss: 0.0622 - 128ms/epoch - 9ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0638 - 129ms/epoch - 9ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0150 - val_loss: 0.0616 - 129ms/epoch - 9ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0718 - 128ms/epoch - 9ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0625 - 129ms/epoch - 9ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0603 - 137ms/epoch - 10ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.0605 - 129ms/epoch - 9ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0646 - 130ms/epoch - 9ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0601 - 130ms/epoch - 9ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0600 - 130ms/epoch - 9ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0612 - 131ms/epoch - 9ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0611 - 133ms/epoch - 10ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0650 - 135ms/epoch - 10ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0710 - 134ms/epoch - 10ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0600 - 133ms/epoch - 9ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0596 - 128ms/epoch - 9ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0602 - 133ms/epoch - 10ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0758 - 132ms/epoch - 9ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0616 - 129ms/epoch - 9ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0622 - 131ms/epoch - 9ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0632 - 136ms/epoch - 10ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0636 - 134ms/epoch - 10ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0600 - 133ms/epoch - 9ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0598 - 134ms/epoch - 10ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0598 - 132ms/epoch - 9ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0630 - 128ms/epoch - 9ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0598 - 130ms/epoch - 9ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0635 - 129ms/epoch - 9ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0608 - 131ms/epoch - 9ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 0.0103 - val_loss: 0.0604 - 129ms/epoch - 9ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0624 - 130ms/epoch - 9ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0666 - 137ms/epoch - 10ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 305ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 29.114487
# 2022-03-20: número de casos reales 7, número de casos predichos 29.077684
# 2022-03-21: número de casos reales 53, número de casos predichos 28.26697
# 2022-03-22: número de casos reales 36, número de casos predichos 28.378923
# 2022-03-23: número de casos reales 32, número de casos predichos 28.799168
# 2022-03-24: número de casos reales 32, número de casos predichos 29.704988
# 2022-03-25: número de casos reales 27, número de casos predichos 28.889734
# 2022-03-26: número de casos reales 13, número de casos predichos 28.925735
# 2022-03-27: número de casos reales 14, número de casos predichos 27.927307
# 2022-03-28: número de casos reales 13, número de casos predichos 27.393238

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-17.11448669, -22.0776844 ,  24.73303032,   7.62107658,
#          3.20083237,   2.29501152,  -1.88973427, -15.92573547,
#        -13.92730713, -14.39323807])

# %%
datos_train = datos_LaGomera_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 212.39811380884674
# Error absoluto medio (MAE) del modelo: 12.317813682556153
# Raíz del error cuadrático medio (RMSE) del modelo: 14.573884650594938

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_atm_scaled = scaler.fit_transform(datos_LaGomera_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_atm_scaled) - dias_prediccion


train = datos_LaGomera_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_atm_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 - 3s - loss: 0.0502 - val_loss: 0.1730 - 3s/epoch - 207ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0446 - val_loss: 0.1370 - 127ms/epoch - 9ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0402 - val_loss: 0.1162 - 125ms/epoch - 9ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0340 - val_loss: 0.0857 - 126ms/epoch - 9ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0303 - val_loss: 0.0701 - 125ms/epoch - 9ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0259 - val_loss: 0.0716 - 126ms/epoch - 9ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0244 - val_loss: 0.0681 - 134ms/epoch - 10ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0244 - val_loss: 0.0684 - 130ms/epoch - 9ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0224 - val_loss: 0.0671 - 127ms/epoch - 9ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0206 - val_loss: 0.0684 - 127ms/epoch - 9ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0214 - val_loss: 0.0772 - 125ms/epoch - 9ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0210 - val_loss: 0.0743 - 125ms/epoch - 9ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0199 - val_loss: 0.0638 - 124ms/epoch - 9ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0188 - val_loss: 0.0690 - 124ms/epoch - 9ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0187 - val_loss: 0.0685 - 129ms/epoch - 9ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0177 - val_loss: 0.0670 - 130ms/epoch - 9ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0186 - val_loss: 0.0646 - 124ms/epoch - 9ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0170 - val_loss: 0.0766 - 127ms/epoch - 9ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0759 - 124ms/epoch - 9ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 0.0174 - val_loss: 0.0618 - 124ms/epoch - 9ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.0623 - 126ms/epoch - 9ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0158 - val_loss: 0.0613 - 129ms/epoch - 9ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0157 - val_loss: 0.0623 - 128ms/epoch - 9ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0590 - 124ms/epoch - 9ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0589 - 125ms/epoch - 9ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0147 - val_loss: 0.0601 - 125ms/epoch - 9ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.0736 - 124ms/epoch - 9ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0768 - 125ms/epoch - 9ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0585 - 126ms/epoch - 9ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0146 - val_loss: 0.0586 - 128ms/epoch - 9ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0717 - 125ms/epoch - 9ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0719 - 123ms/epoch - 9ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0644 - 125ms/epoch - 9ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0642 - 126ms/epoch - 9ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0730 - 126ms/epoch - 9ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0614 - 124ms/epoch - 9ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0580 - 124ms/epoch - 9ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0580 - 125ms/epoch - 9ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0608 - 128ms/epoch - 9ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0642 - 129ms/epoch - 9ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0617 - 128ms/epoch - 9ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0591 - 129ms/epoch - 9ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0577 - 124ms/epoch - 9ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0584 - 127ms/epoch - 9ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0622 - 128ms/epoch - 9ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0585 - 128ms/epoch - 9ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0594 - 126ms/epoch - 9ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0612 - 129ms/epoch - 9ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0578 - 127ms/epoch - 9ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0630 - 125ms/epoch - 9ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 298ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 28.738403
# 2022-03-20: número de casos reales 7, número de casos predichos 28.826258
# 2022-03-21: número de casos reales 53, número de casos predichos 28.084423
# 2022-03-22: número de casos reales 36, número de casos predichos 28.315649
# 2022-03-23: número de casos reales 32, número de casos predichos 28.700321
# 2022-03-24: número de casos reales 32, número de casos predichos 29.684645
# 2022-03-25: número de casos reales 27, número de casos predichos 28.322802
# 2022-03-26: número de casos reales 13, número de casos predichos 28.117878
# 2022-03-27: número de casos reales 14, número de casos predichos 26.740763
# 2022-03-28: número de casos reales 13, número de casos predichos 25.8948

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-16.73840332, -21.82625771,  24.91557693,   7.68435097,
#          3.2996788 ,   2.3153553 ,  -1.32280159, -15.11787796,
#        -12.74076271, -12.89480019])

# %%
datos_train = datos_LaGomera_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 201.15465896566238
# Error absoluto medio (MAE) del modelo: 11.885586547851563
# Raíz del error cuadrático medio (RMSE) del modelo: 14.182900231111491

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_total_scaled = scaler.fit_transform(datos_LaGomera_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_total_scaled) - dias_prediccion


train = datos_LaGomera_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_total_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 14/14 - 3s - loss: 0.0451 - val_loss: 0.1458 - 3s/epoch - 212ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0379 - val_loss: 0.0898 - 151ms/epoch - 11ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0332 - val_loss: 0.0811 - 150ms/epoch - 11ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0289 - val_loss: 0.0737 - 148ms/epoch - 11ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0263 - val_loss: 0.0682 - 151ms/epoch - 11ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0260 - val_loss: 0.0736 - 149ms/epoch - 11ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0243 - val_loss: 0.0681 - 151ms/epoch - 11ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.0232 - val_loss: 0.0657 - 150ms/epoch - 11ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0215 - val_loss: 0.0667 - 150ms/epoch - 11ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0204 - val_loss: 0.0745 - 153ms/epoch - 11ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0201 - val_loss: 0.0779 - 151ms/epoch - 11ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0185 - val_loss: 0.0825 - 151ms/epoch - 11ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0634 - 149ms/epoch - 11ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0183 - val_loss: 0.0629 - 148ms/epoch - 11ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0617 - 148ms/epoch - 11ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0162 - val_loss: 0.0614 - 148ms/epoch - 11ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0152 - val_loss: 0.0647 - 154ms/epoch - 11ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0164 - val_loss: 0.0607 - 152ms/epoch - 11ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.0636 - 148ms/epoch - 11ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 0.0133 - val_loss: 0.0605 - 149ms/epoch - 11ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0648 - 148ms/epoch - 11ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0144 - val_loss: 0.0646 - 149ms/epoch - 11ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0148 - val_loss: 0.0605 - 151ms/epoch - 11ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0607 - 150ms/epoch - 11ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0597 - 150ms/epoch - 11ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0695 - 149ms/epoch - 11ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0140 - val_loss: 0.0611 - 151ms/epoch - 11ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0594 - 150ms/epoch - 11ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0594 - 149ms/epoch - 11ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.0602 - 149ms/epoch - 11ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0597 - 152ms/epoch - 11ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0594 - 150ms/epoch - 11ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0603 - 148ms/epoch - 11ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0592 - 149ms/epoch - 11ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0613 - 152ms/epoch - 11ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0594 - 150ms/epoch - 11ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0600 - 149ms/epoch - 11ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0693 - 147ms/epoch - 11ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0598 - 151ms/epoch - 11ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0118 - val_loss: 0.0602 - 149ms/epoch - 11ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0598 - 150ms/epoch - 11ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0595 - 148ms/epoch - 11ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0594 - 149ms/epoch - 11ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0594 - 150ms/epoch - 11ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0608 - 150ms/epoch - 11ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0599 - 152ms/epoch - 11ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0713 - 148ms/epoch - 11ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 0.0107 - val_loss: 0.0657 - 154ms/epoch - 11ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0617 - 148ms/epoch - 11ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0598 - 147ms/epoch - 11ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 289ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 23.964813
# 2022-03-20: número de casos reales 7, número de casos predichos 23.896416
# 2022-03-21: número de casos reales 53, número de casos predichos 23.207363
# 2022-03-22: número de casos reales 36, número de casos predichos 23.045162
# 2022-03-23: número de casos reales 32, número de casos predichos 23.149576
# 2022-03-24: número de casos reales 32, número de casos predichos 23.600521
# 2022-03-25: número de casos reales 27, número de casos predichos 23.539047
# 2022-03-26: número de casos reales 13, número de casos predichos 23.483845
# 2022-03-27: número de casos reales 14, número de casos predichos 22.615976
# 2022-03-28: número de casos reales 13, número de casos predichos 21.781384

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-11.96481323, -16.89641571,  29.79263687,  12.9548378 ,
#          8.85042381,   8.39947891,   3.46095276, -10.48384476,
#         -8.61597633,  -8.78138351])

# %%
datos_train = datos_LaGomera_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 190.6192840858792
# Error absoluto medio (MAE) del modelo: 12.020076370239257
# Raíz del error cuadrático medio (RMSE) del modelo: 13.806494272112642
