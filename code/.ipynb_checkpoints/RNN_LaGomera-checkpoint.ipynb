# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de La Gomera

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.legend()
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, indices, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    color_isla = 'pink'
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True, 
                   input_shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
    
    return modelo
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_LaGomera = datos[datos['isla'] == 'LA GOMERA']

datos_LaGomera = datos_LaGomera.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'La Gomera'         # Isla a la que se está realziando el estudio
fechas = datos_LaGomera.tail(dias_prediccion).index # Fechas de los días a predecir

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_LaGomera_uni = datos_LaGomera[objetivo]
datos_LaGomera_uni_arr = np.array(datos_LaGomera_uni).reshape(-1, 1)

datos_LaGomera_mult_covid = datos_LaGomera[variables_covid]
datos_LaGomera_mult_atm = datos_LaGomera[variables_atm]
datos_LaGomera_mult_total = datos_LaGomera[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_uni_scaled = scaler.fit_transform(datos_LaGomera_uni_arr)

# %%
n_train = len(datos_LaGomera_uni_scaled) - dias_prediccion


train = datos_LaGomera_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_uni_scaled[n_train - dias_prediccion:len(datos_LaGomera_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 5s 109ms/step - loss: 0.0457 - val_loss: 0.2081
# Epoch 2/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0415 - val_loss: 0.1860
# Epoch 3/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0393 - val_loss: 0.1712
# Epoch 4/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0380 - val_loss: 0.1665
# Epoch 5/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0368 - val_loss: 0.1556
# Epoch 6/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0355 - val_loss: 0.1463
# Epoch 7/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0333 - val_loss: 0.1385
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0325 - val_loss: 0.1211
# Epoch 9/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0299 - val_loss: 0.1059
# Epoch 10/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0272 - val_loss: 0.0897
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0243 - val_loss: 0.0701
# Epoch 12/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0237 - val_loss: 0.0640
# Epoch 13/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0206 - val_loss: 0.0667
# Epoch 14/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0207 - val_loss: 0.0668
# Epoch 15/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0203 - val_loss: 0.0696
# Epoch 16/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0188 - val_loss: 0.0686
# Epoch 17/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0180 - val_loss: 0.0641
# Epoch 18/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0176 - val_loss: 0.0729
# Epoch 19/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0188 - val_loss: 0.0611
# Epoch 20/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0181 - val_loss: 0.0628
# Epoch 21/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0184 - val_loss: 0.0616
# Epoch 22/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0176 - val_loss: 0.0623
# Epoch 23/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0173 - val_loss: 0.0628
# Epoch 24/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0164 - val_loss: 0.0604
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0643
# Epoch 26/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0171 - val_loss: 0.0603
# Epoch 27/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0600
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0171 - val_loss: 0.0605
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0174 - val_loss: 0.0601
# Epoch 30/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.0601
# Epoch 31/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0161 - val_loss: 0.0619
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0159 - val_loss: 0.0597
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0623
# Epoch 34/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0154 - val_loss: 0.0623
# Epoch 35/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0151 - val_loss: 0.0589
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0142 - val_loss: 0.0637
# Epoch 37/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0138 - val_loss: 0.0620
# Epoch 38/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0603
# Epoch 39/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0149 - val_loss: 0.0612
# Epoch 40/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0152 - val_loss: 0.0587
# Epoch 41/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0585
# Epoch 42/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0146 - val_loss: 0.0593
# Epoch 43/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0138 - val_loss: 0.0656
# Epoch 44/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0132 - val_loss: 0.0590
# Epoch 45/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0132 - val_loss: 0.0604
# Epoch 46/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0137 - val_loss: 0.0637
# Epoch 47/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0146 - val_loss: 0.0636
# Epoch 48/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0141 - val_loss: 0.0617
# Epoch 49/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0132 - val_loss: 0.0587
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0147 - val_loss: 0.0575

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 543ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 24.155222
# 2022-03-20: número de casos reales 7, número de casos predichos 24.480303
# 2022-03-21: número de casos reales 53, número de casos predichos 23.773043
# 2022-03-22: número de casos reales 36, número de casos predichos 24.607794
# 2022-03-23: número de casos reales 32, número de casos predichos 25.69938
# 2022-03-24: número de casos reales 32, número de casos predichos 27.71659
# 2022-03-25: número de casos reales 27, número de casos predichos 25.062803
# 2022-03-26: número de casos reales 13, número de casos predichos 25.026999
# 2022-03-27: número de casos reales 14, número de casos predichos 23.13442
# 2022-03-28: número de casos reales 13, número de casos predichos 22.395975

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaGomera_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 181.5476606804212
# Error absoluto medio (MAE) del modelo: 11.333330726623535
# Raíz del error cuadrático medio (RMSE) del modelo: 13.473962322955382

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_covid_scaled = scaler.fit_transform(datos_LaGomera_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_covid_scaled) - dias_prediccion


train = datos_LaGomera_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_covid_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 7s 130ms/step - loss: 0.0474 - val_loss: 0.1802
# Epoch 2/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0412 - val_loss: 0.1503
# Epoch 3/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0364 - val_loss: 0.1256
# Epoch 4/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0333 - val_loss: 0.1055
# Epoch 5/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0295 - val_loss: 0.0766
# Epoch 6/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0278 - val_loss: 0.0738
# Epoch 7/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0253 - val_loss: 0.0670
# Epoch 8/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0241 - val_loss: 0.0665
# Epoch 9/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0244 - val_loss: 0.0663
# Epoch 10/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0228 - val_loss: 0.0658
# Epoch 11/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0227 - val_loss: 0.0685
# Epoch 12/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0212 - val_loss: 0.0740
# Epoch 13/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0231 - val_loss: 0.0716
# Epoch 14/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0223 - val_loss: 0.0643
# Epoch 15/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0210 - val_loss: 0.0668
# Epoch 16/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0221 - val_loss: 0.0738
# Epoch 17/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0212 - val_loss: 0.0671
# Epoch 18/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0200 - val_loss: 0.0668
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0651
# Epoch 20/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0183 - val_loss: 0.0657
# Epoch 21/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0197 - val_loss: 0.0655
# Epoch 22/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0183 - val_loss: 0.0633
# Epoch 23/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0178 - val_loss: 0.0686
# Epoch 24/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0183 - val_loss: 0.0703
# Epoch 25/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0171 - val_loss: 0.0620
# Epoch 26/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0171 - val_loss: 0.0685
# Epoch 27/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0184 - val_loss: 0.0632
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0166 - val_loss: 0.0634
# Epoch 29/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0145 - val_loss: 0.0650
# Epoch 30/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0162 - val_loss: 0.0606
# Epoch 31/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0151 - val_loss: 0.0662
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0154 - val_loss: 0.0631
# Epoch 33/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0680
# Epoch 34/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0606
# Epoch 35/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0150 - val_loss: 0.0601
# Epoch 36/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0147 - val_loss: 0.0599
# Epoch 37/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0153 - val_loss: 0.0595
# Epoch 38/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0161 - val_loss: 0.0599
# Epoch 39/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0139 - val_loss: 0.0599
# Epoch 40/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0139 - val_loss: 0.0641
# Epoch 41/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0131 - val_loss: 0.0606
# Epoch 42/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0141 - val_loss: 0.0601
# Epoch 43/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0591
# Epoch 44/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0133 - val_loss: 0.0590
# Epoch 45/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0144 - val_loss: 0.0658
# Epoch 46/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0136 - val_loss: 0.0610
# Epoch 47/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0132 - val_loss: 0.0594
# Epoch 48/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0131 - val_loss: 0.0600
# Epoch 49/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0133 - val_loss: 0.0596
# Epoch 50/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0126 - val_loss: 0.0607

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 562ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 27.30107
# 2022-03-20: número de casos reales 7, número de casos predichos 27.388329
# 2022-03-21: número de casos reales 53, número de casos predichos 26.469988
# 2022-03-22: número de casos reales 36, número de casos predichos 26.7106
# 2022-03-23: número de casos reales 32, número de casos predichos 27.22892
# 2022-03-24: número de casos reales 32, número de casos predichos 28.409641
# 2022-03-25: número de casos reales 27, número de casos predichos 26.54922
# 2022-03-26: número de casos reales 13, número de casos predichos 26.366426
# 2022-03-27: número de casos reales 14, número de casos predichos 25.029955
# 2022-03-28: número de casos reales 13, número de casos predichos 24.383587

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaGomera_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 190.5705555471148
# Error absoluto medio (MAE) del modelo: 11.610099792480469
# Raíz del error cuadrático medio (RMSE) del modelo: 13.804729463017912

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_atm_scaled = scaler.fit_transform(datos_LaGomera_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_atm_scaled) - dias_prediccion


train = datos_LaGomera_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_atm_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 9s 83ms/step - loss: 0.0463 - val_loss: 0.1748
# Epoch 2/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0423 - val_loss: 0.1614
# Epoch 3/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0389 - val_loss: 0.1401
# Epoch 4/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0364 - val_loss: 0.1198
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0322 - val_loss: 0.0843
# Epoch 6/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0296 - val_loss: 0.0734
# Epoch 7/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0267 - val_loss: 0.0698
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0252 - val_loss: 0.0692
# Epoch 9/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0247 - val_loss: 0.0691
# Epoch 10/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0237 - val_loss: 0.0713
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0225 - val_loss: 0.0685
# Epoch 12/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0223 - val_loss: 0.0675
# Epoch 13/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0231 - val_loss: 0.0670
# Epoch 14/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0217 - val_loss: 0.0666
# Epoch 15/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0205 - val_loss: 0.0666
# Epoch 16/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0214 - val_loss: 0.0692
# Epoch 17/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0200 - val_loss: 0.0665
# Epoch 18/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0198 - val_loss: 0.0651
# Epoch 19/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0204 - val_loss: 0.0669
# Epoch 20/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0188 - val_loss: 0.0736
# Epoch 21/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0187 - val_loss: 0.0641
# Epoch 22/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0654
# Epoch 23/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0186 - val_loss: 0.0642
# Epoch 24/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0190 - val_loss: 0.0631
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0632
# Epoch 26/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0169 - val_loss: 0.0625
# Epoch 27/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0182 - val_loss: 0.0620
# Epoch 28/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0641
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0173 - val_loss: 0.0616
# Epoch 30/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0166 - val_loss: 0.0630
# Epoch 31/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0157 - val_loss: 0.0623
# Epoch 32/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0150 - val_loss: 0.0623
# Epoch 33/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0161 - val_loss: 0.0607
# Epoch 34/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0158 - val_loss: 0.0613
# Epoch 35/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0151 - val_loss: 0.0608
# Epoch 36/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0153 - val_loss: 0.0605
# Epoch 37/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0149 - val_loss: 0.0600
# Epoch 38/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0147 - val_loss: 0.0626
# Epoch 39/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0154 - val_loss: 0.0601
# Epoch 40/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0142 - val_loss: 0.0599
# Epoch 41/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0139 - val_loss: 0.0647
# Epoch 42/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0138 - val_loss: 0.0602
# Epoch 43/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0132 - val_loss: 0.0604
# Epoch 44/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0137 - val_loss: 0.0623
# Epoch 45/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0139 - val_loss: 0.0590
# Epoch 46/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0133 - val_loss: 0.0589
# Epoch 47/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0134 - val_loss: 0.0628
# Epoch 48/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0138 - val_loss: 0.0591
# Epoch 49/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0130 - val_loss: 0.0585
# Epoch 50/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0140 - val_loss: 0.0597

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 569ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 26.465197
# 2022-03-20: número de casos reales 7, número de casos predichos 26.602293
# 2022-03-21: número de casos reales 53, número de casos predichos 25.818962
# 2022-03-22: número de casos reales 36, número de casos predichos 26.119202
# 2022-03-23: número de casos reales 32, número de casos predichos 26.591835
# 2022-03-24: número de casos reales 32, número de casos predichos 28.047594
# 2022-03-25: número de casos reales 27, número de casos predichos 26.437057
# 2022-03-26: número de casos reales 13, número de casos predichos 26.230173
# 2022-03-27: número de casos reales 14, número de casos predichos 24.68933
# 2022-03-28: número de casos reales 13, número de casos predichos 23.878105

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaGomera_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 188.27498771279824
# Error absoluto medio (MAE) del modelo: 11.585044670104981
# Raíz del error cuadrático medio (RMSE) del modelo: 13.721333306672433

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_total_scaled = scaler.fit_transform(datos_LaGomera_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaGomera_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaGomera_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaGomera_mult_total_scaled) - dias_prediccion


train = datos_LaGomera_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaGomera_mult_total_scaled[n_train - dias_prediccion:len(datos_LaGomera_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 9s 83ms/step - loss: 0.0460 - val_loss: 0.1615
# Epoch 2/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0412 - val_loss: 0.1385
# Epoch 3/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0361 - val_loss: 0.1132
# Epoch 4/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0319 - val_loss: 0.0862
# Epoch 5/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0288 - val_loss: 0.0783
# Epoch 6/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0285 - val_loss: 0.0729
# Epoch 7/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0263 - val_loss: 0.0687
# Epoch 8/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0251 - val_loss: 0.0682
# Epoch 9/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0238 - val_loss: 0.0675
# Epoch 10/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0234 - val_loss: 0.0709
# Epoch 11/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0232 - val_loss: 0.0666
# Epoch 12/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0222 - val_loss: 0.0665
# Epoch 13/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0216 - val_loss: 0.0704
# Epoch 14/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0212 - val_loss: 0.0656
# Epoch 15/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0200 - val_loss: 0.0664
# Epoch 16/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0202 - val_loss: 0.0739
# Epoch 17/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0207 - val_loss: 0.0677
# Epoch 18/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0192 - val_loss: 0.0669
# Epoch 19/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0191 - val_loss: 0.0638
# Epoch 20/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0182 - val_loss: 0.0640
# Epoch 21/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0182 - val_loss: 0.0743
# Epoch 22/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0174 - val_loss: 0.0634
# Epoch 23/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0174 - val_loss: 0.0636
# Epoch 24/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0168 - val_loss: 0.0636
# Epoch 25/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0165 - val_loss: 0.0624
# Epoch 26/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0162 - val_loss: 0.0619
# Epoch 27/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0156 - val_loss: 0.0652
# Epoch 28/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0164 - val_loss: 0.0698
# Epoch 29/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0165 - val_loss: 0.0665
# Epoch 30/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0152 - val_loss: 0.0632
# Epoch 31/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0151 - val_loss: 0.0703
# Epoch 32/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0145 - val_loss: 0.0615
# Epoch 33/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0142 - val_loss: 0.0619
# Epoch 34/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0137 - val_loss: 0.0642
# Epoch 35/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0145 - val_loss: 0.0620
# Epoch 36/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0139 - val_loss: 0.0621
# Epoch 37/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0136 - val_loss: 0.0702
# Epoch 38/50
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0148 - val_loss: 0.0610
# Epoch 39/50
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0135 - val_loss: 0.0899
# Epoch 40/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0141 - val_loss: 0.0610
# Epoch 41/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0134 - val_loss: 0.0617
# Epoch 42/50
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0141 - val_loss: 0.0602
# Epoch 43/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0131 - val_loss: 0.0610
# Epoch 44/50
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0124 - val_loss: 0.0597
# Epoch 45/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0136 - val_loss: 0.0594
# Epoch 46/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0126 - val_loss: 0.0597
# Epoch 47/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0123 - val_loss: 0.0596
# Epoch 48/50
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0126 - val_loss: 0.0616
# Epoch 49/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0111 - val_loss: 0.0598
# Epoch 50/50
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0125 - val_loss: 0.0625

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 12, número de casos predichos 27.972174
# 2022-03-20: número de casos reales 7, número de casos predichos 27.984356
# 2022-03-21: número de casos reales 53, número de casos predichos 27.21236
# 2022-03-22: número de casos reales 36, número de casos predichos 27.350773
# 2022-03-23: número de casos reales 32, número de casos predichos 27.76098
# 2022-03-24: número de casos reales 32, número de casos predichos 28.794003
# 2022-03-25: número de casos reales 27, número de casos predichos 27.604908
# 2022-03-26: número de casos reales 13, número de casos predichos 27.400648
# 2022-03-27: número de casos reales 14, número de casos predichos 26.010408
# 2022-03-28: número de casos reales 13, número de casos predichos 25.075733

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaGomera_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 196.13305402523693
# Error absoluto medio (MAE) del modelo: 11.793011093139649
# Raíz del error cuadrático medio (RMSE) del modelo: 14.004751123288015
