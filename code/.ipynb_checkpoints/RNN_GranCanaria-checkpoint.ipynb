# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de Gran canaria

# %% [markdown]
# En este estudio se analiza la evolución de la pandemia de COVID-19 en la isla de Gran Canaria y la influencia de factores como los atmosféricas en la evolución de dicha enfermedad. Para este fin se utiliza el modelo de red neuronal recurrente mediante LSTM (Long Short-Term Memory) tanto univariable como multivariable.
#
# El estudio se fragmenta en 4 partes:
# * modelado univariable donde se emplea únicamente la variable objetivo.
# * modelado multivariable empleando las variables pandémicas. Dichas variables son:
#     * pcr_total: Número total de pruebas PCR realizadas.
#     * Urg_cv: Ingresos en el servicio de urgencias por COVID19.
#     * HPT_cv19: Ocupación del resto de camas para pacientes COVID.
#     * CCR_cv19: Ocupación de las unidades críticas con respirador para pacientes COVID.
# * modelado multivariable empleando las variables atmosféricas:
#     * tmin: Temperatura mínima diaria.
#     * tmed: Temperatura media diaria.
#     * presMax: Presión máxima al nivel de la estación.
# * modelado multivariable con todas las variables.

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    ''' Método que convierte los datos en un modelo supervisado, donde asigna el valor de número de casos como objetivo(y)
        y los valores del número de días indicado anteriores como variables del objetivo.
    
    Args:
        datos (DataFrame): Conjunto de datos a dividir en variables(X) y objetivo (y)
        dias: número de días predecesores asociado a cada valor
    '''
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    
    ''' Método que visualiza un gráfico con la comparativa entre el número de casos reales y los predichos
    
    Args:
        y_test (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
        fechas(Serie): Valores de fecha de los datos
        tit(string): título del gráfico
    '''
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.legend()
    plt.show()
    
def visualizar_historico(train, y_test, y_pred, variable, dias_historico, indices, tit, color, dif):
    ''' Método que visualiza un gráfico con la comparativa entre el número de casos reales y los predichos
    y muestra el historico de casos en función del número de días que indiquemos que muestre
    
    Args:
        train (Serie): Conjunto de datos de entrenamiento
        y_test (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
        variable (string): Variable objetivo
        dias_historico (integer): días hacia atrás a mostrar del historico
        tit (string): título del gráfico
        color (string): color de la isla para visualizar
        dif(Serie): Diferencia de los valores predichos y los reales
    '''
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    plt.bar(indices, dif, width=0.5, color='black', alpha=0.2, align='edge', label='Diferencia')
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=70)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
        ''' Método que realiza el entrenamiento de la red neuronal
    
    Args:
        X_train(Serie): Conjunto de entrenamiento
        y_train(Serie): Variable objetivo del modelo supervisado 
        X_test(Serie): Conjunto de test
        y_test(Serie): Variable objetivo del conjunto de test
    '''
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    historico = modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=32, verbose=2)
    
    return modelo, historico
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    ''' Método que visualiza por pantalla en formato de texto el número de csaos reales y los predichos por el algoritmo
    
    Args:
        y_test (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
        variable(string): Variable objetivo
    '''
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))
        
def visualizar_perdida(historico):
    ''' Método que visualiza la perdida en el entrenamiento de la red neuronal
    
    Args:
        historico: historial de pérdida en el entrenamiento
    '''
    plt.plot(historico.history['loss'], label='train')
    plt.plot(historico.history['val_loss'], label='test')
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.title('Pérdida del modelo')
    plt.legend()
    plt.show()

# %% [markdown]
# Inicialmente cargamos los datos del fichero con los datos procesados anteriormente y obtenemos los datos únicamente para la isla de Gran Canaria.

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_GranCanaria = datos[datos['isla'] == 'GRAN CANARIA']
datos_GranCanaria = datos_GranCanaria.set_index('fecha')

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a agrupar 
isla = 'Gran Canaria'     # Isla a la que se está realziando el estudio
fechas = datos_GranCanaria.tail(dias_prediccion).index # Fechas de los días a predecir
color_isla = 'sienna' # Color de la isla en las visualizaciones
n_dias_train_vis = 100    # Número de días del conjunto de train a visualizar en el conjunto de train

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %% [markdown]
# Separamos los datos en función de las variables a emplear en cada uno de los estudios que se van a realizar.

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_GranCanaria_uni = datos_GranCanaria[objetivo]
datos_GranCanaria_uni_arr = np.array(datos_GranCanaria_uni).reshape(-1, 1)

datos_GranCanaria_mult_covid = datos_GranCanaria[variables_covid]
datos_GranCanaria_mult_atm = datos_GranCanaria[variables_atm]
datos_GranCanaria_mult_total = datos_GranCanaria[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %% [markdown]
# Realizamos el análisis con los datos únicamente de la variable objetivo obteniendo un modelo de reuronal recurrente univariable.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_uni_scaled = scaler.fit_transform(datos_GranCanaria_uni_arr)

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_GranCanaria_uni_scaled) - dias_prediccion


train = datos_GranCanaria_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_uni_scaled[n_train - dias_prediccion:len(datos_GranCanaria_uni_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0509 - val_loss: 0.0612 - 3s/epoch - 214ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0379 - val_loss: 0.0400 - 123ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0300 - val_loss: 0.0392 - 119ms/epoch - 8ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0264 - val_loss: 0.0339 - 118ms/epoch - 8ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0232 - val_loss: 0.0302 - 120ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0234 - val_loss: 0.0308 - 119ms/epoch - 8ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0282 - 120ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0201 - val_loss: 0.0272 - 118ms/epoch - 8ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0187 - val_loss: 0.0296 - 121ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0174 - val_loss: 0.0273 - 119ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0171 - val_loss: 0.0263 - 120ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0178 - val_loss: 0.0239 - 118ms/epoch - 8ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0230 - 119ms/epoch - 8ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0165 - val_loss: 0.0256 - 118ms/epoch - 8ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0159 - val_loss: 0.0259 - 118ms/epoch - 8ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0159 - val_loss: 0.0233 - 119ms/epoch - 8ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0147 - val_loss: 0.0274 - 121ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0141 - val_loss: 0.0228 - 119ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0239 - 119ms/epoch - 8ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0148 - val_loss: 0.0211 - 121ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0218 - 119ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0208 - 118ms/epoch - 8ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0125 - val_loss: 0.0203 - 121ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0207 - 119ms/epoch - 8ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0197 - 118ms/epoch - 8ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0121 - val_loss: 0.0198 - 121ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0195 - 119ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0131 - val_loss: 0.0196 - 120ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0123 - val_loss: 0.0192 - 120ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0212 - 121ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0209 - 118ms/epoch - 8ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0191 - 119ms/epoch - 8ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0187 - 118ms/epoch - 8ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0180 - 120ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0215 - 118ms/epoch - 8ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0179 - 123ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0203 - 121ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0184 - 119ms/epoch - 8ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0192 - 119ms/epoch - 8ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0106 - val_loss: 0.0177 - 119ms/epoch - 8ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 323ms/step

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 511.17154
# 2022-03-20: número de casos reales 461, número de casos predichos 519.6045
# 2022-03-21: número de casos reales 948, número de casos predichos 526.812
# 2022-03-22: número de casos reales 966, número de casos predichos 545.0579
# 2022-03-23: número de casos reales 948, número de casos predichos 605.92786
# 2022-03-24: número de casos reales 790, número de casos predichos 672.2097
# 2022-03-25: número de casos reales 741, número de casos predichos 708.54114
# 2022-03-26: número de casos reales 428, número de casos predichos 745.45776
# 2022-03-27: número de casos reales 368, número de casos predichos 779.4446
# 2022-03-28: número de casos reales 528, número de casos predichos 786.7944

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([  21.82846069,  -58.60449219,  421.18798828,  420.94207764,
#         342.07214355,  117.7902832 ,   32.4588623 , -317.45776367,
#        -411.44458008, -258.79437256])

# %%
datos_train = datos_GranCanaria_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Para la evaluación del modelo se utilizarán las siguientes estimadores:
# * MAE: Error absoluto medio
# * MSE: Error cuadrático medio
# * RMSE: Raíz del error cuadrático medio

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 82748.46038128147
# Error absoluto medio (MAE) del modelo: 240.2581024169922
# Raíz del error cuadrático medio (RMSE) del modelo: 287.6603211798274

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %% [markdown]
# Realizamos el análisis con los datos pandémicos obteniendo un modelo de red neuronal multivariable en base a dichas variables.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max. Dado que poseemos más de una variable también creamos un escalador univariable para poder desnormalizar los datos predichos en la fase final.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled = scaler.fit_transform(datos_GranCanaria_mult_covid)

# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_covid[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_GranCanaria_mult_covid_scaled) - dias_prediccion


train = datos_GranCanaria_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_covid_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_covid_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0431 - val_loss: 0.0476 - 3s/epoch - 222ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0330 - val_loss: 0.0334 - 137ms/epoch - 10ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0276 - val_loss: 0.0408 - 132ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0239 - val_loss: 0.0396 - 130ms/epoch - 9ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0210 - val_loss: 0.0420 - 132ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0230 - val_loss: 0.0335 - 130ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0177 - val_loss: 0.0385 - 131ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0184 - val_loss: 0.0446 - 131ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0168 - val_loss: 0.0319 - 130ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0152 - val_loss: 0.0391 - 131ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0154 - val_loss: 0.0299 - 130ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0341 - 129ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0135 - val_loss: 0.0373 - 130ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0140 - val_loss: 0.0379 - 128ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0303 - 129ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0355 - 131ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0373 - 131ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0257 - 131ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0319 - 134ms/epoch - 10ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0239 - 134ms/epoch - 10ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0098 - val_loss: 0.0326 - 131ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0296 - 131ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0097 - val_loss: 0.0260 - 135ms/epoch - 10ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0327 - 132ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0084 - val_loss: 0.0323 - 130ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0078 - val_loss: 0.0284 - 131ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0083 - val_loss: 0.0463 - 132ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0082 - val_loss: 0.0318 - 132ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0081 - val_loss: 0.0382 - 132ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0090 - val_loss: 0.0291 - 129ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0079 - val_loss: 0.0288 - 130ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0089 - val_loss: 0.0282 - 129ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0087 - val_loss: 0.0303 - 129ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0083 - val_loss: 0.0274 - 130ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0316 - 129ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0075 - val_loss: 0.0250 - 129ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0078 - val_loss: 0.0244 - 129ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0087 - val_loss: 0.0255 - 130ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0290 - 131ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0076 - val_loss: 0.0269 - 129ms/epoch - 9ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 287ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 376.62796
# 2022-03-20: número de casos reales 461, número de casos predichos 360.30917
# 2022-03-21: número de casos reales 948, número de casos predichos 325.62946
# 2022-03-22: número de casos reales 966, número de casos predichos 347.51907
# 2022-03-23: número de casos reales 948, número de casos predichos 431.20166
# 2022-03-24: número de casos reales 790, número de casos predichos 520.2799
# 2022-03-25: número de casos reales 741, número de casos predichos 574.40857
# 2022-03-26: número de casos reales 428, número de casos predichos 607.3597
# 2022-03-27: número de casos reales 368, número de casos predichos 677.72485
# 2022-03-28: número de casos reales 528, número de casos predichos 699.38324

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_GranCanaria_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 132950.83602993106
# Error absoluto medio (MAE) del modelo: 311.1491973876953
# Raíz del error cuadrático medio (RMSE) del modelo: 364.6242394985982

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %% [markdown]
# Realizamos el análisis con los datos atmosféricos obteniendo un modelo de red neuronal multivariable en base a dichas variables.
#
# En primer lugar normalizamos los datos para poder utilizar la red neuronal con LSTM para ello se emplea la normalización Min-Max. Dado que poseemos más de una variable también creamos un escalador univariable para poder desnormalizar los datos predichos en la fase final.

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled = scaler.fit_transform(datos_GranCanaria_mult_atm)

# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_atm[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_GranCanaria_mult_atm_scaled) - dias_prediccion


train = datos_GranCanaria_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_atm_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_atm_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0519 - val_loss: 0.0542 - 3s/epoch - 209ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0422 - val_loss: 0.0453 - 128ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0317 - val_loss: 0.0309 - 126ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0274 - val_loss: 0.0344 - 126ms/epoch - 9ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0241 - val_loss: 0.0317 - 127ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0245 - val_loss: 0.0290 - 126ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0227 - val_loss: 0.0294 - 129ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0231 - val_loss: 0.0310 - 126ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0194 - val_loss: 0.0277 - 127ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0183 - val_loss: 0.0319 - 130ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0186 - val_loss: 0.0270 - 127ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0176 - val_loss: 0.0280 - 127ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0177 - val_loss: 0.0272 - 125ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0239 - 125ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0171 - val_loss: 0.0251 - 126ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0163 - val_loss: 0.0227 - 125ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.0217 - 128ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0211 - 126ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0263 - 129ms/epoch - 9ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0213 - 128ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0139 - val_loss: 0.0216 - 126ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0211 - 126ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0189 - 127ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0187 - 128ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0194 - 130ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0201 - 129ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0203 - 127ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0122 - val_loss: 0.0187 - 126ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0207 - 128ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0099 - val_loss: 0.0187 - 125ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0200 - 128ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0094 - val_loss: 0.0182 - 127ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0178 - 125ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0098 - val_loss: 0.0201 - 127ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0101 - val_loss: 0.0183 - 128ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0188 - 125ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0104 - val_loss: 0.0174 - 125ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0103 - val_loss: 0.0186 - 125ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0097 - val_loss: 0.0193 - 128ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0088 - val_loss: 0.0195 - 125ms/epoch - 9ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 285ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 405.33884
# 2022-03-20: número de casos reales 461, número de casos predichos 415.76352
# 2022-03-21: número de casos reales 948, número de casos predichos 430.20813
# 2022-03-22: número de casos reales 966, número de casos predichos 458.4919
# 2022-03-23: número de casos reales 948, número de casos predichos 511.32593
# 2022-03-24: número de casos reales 790, número de casos predichos 559.77295
# 2022-03-25: número de casos reales 741, número de casos predichos 602.94904
# 2022-03-26: número de casos reales 428, número de casos predichos 639.6426
# 2022-03-27: número de casos reales 368, número de casos predichos 653.5388
# 2022-03-28: número de casos reales 528, número de casos predichos 645.50433

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_GranCanaria_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 94689.56662162868
# Error absoluto medio (MAE) del modelo: 261.7835418701172
# Raíz del error cuadrático medio (RMSE) del modelo: 307.7166986395582

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled = scaler.fit_transform(datos_GranCanaria_mult_total)

# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_total[objetivo]).reshape(-1, 1))

# %% [markdown]
# Dividimos los datos en conjunto de entrenamiento y test. Para el conjunto de datos de test se emplean los últimos 10 días de la serie temporal y para el conjunto de entrenamiento el resto de datos.

# %%
n_train = len(datos_GranCanaria_mult_total_scaled) - dias_prediccion


train = datos_GranCanaria_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_total_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_total_scaled), :]

# %% [markdown]
# Para crear la red neuronal, creamos un problema supervisado, para ello asociaremos el valor de cada día a los valores de los 10 días anteriores. De esta forma en el conjunto de entrenamiento en y_train tenemos los valores del número de casos de cada día y en X-train tenemos grupos de 10 con los 10 valores de números de casos anteriores al actual. Lo mismo ocurre con los valores de test que servirán para realizar la predicción en y_test tenemos los valores que queremos predecir y en X_test los valores de los 10 días que preceden al día a realizar la predicción.

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %% [markdown]
# Entrenamos el modelo con el problema supervisado generado anteriormente.

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0547 - val_loss: 0.0547 - 3s/epoch - 207ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0403 - val_loss: 0.0429 - 159ms/epoch - 11ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0332 - val_loss: 0.0416 - 156ms/epoch - 11ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0296 - val_loss: 0.0420 - 153ms/epoch - 11ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0281 - val_loss: 0.0466 - 154ms/epoch - 11ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0254 - val_loss: 0.0380 - 154ms/epoch - 11ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0221 - val_loss: 0.0332 - 155ms/epoch - 11ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0227 - val_loss: 0.0322 - 155ms/epoch - 11ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0193 - val_loss: 0.0335 - 156ms/epoch - 11ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0188 - val_loss: 0.0295 - 156ms/epoch - 11ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0192 - val_loss: 0.0292 - 154ms/epoch - 11ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0171 - val_loss: 0.0287 - 155ms/epoch - 11ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0151 - val_loss: 0.0320 - 155ms/epoch - 11ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0300 - 156ms/epoch - 11ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0134 - val_loss: 0.0285 - 154ms/epoch - 11ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0138 - val_loss: 0.0253 - 159ms/epoch - 11ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0117 - val_loss: 0.0244 - 155ms/epoch - 11ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0223 - 155ms/epoch - 11ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0354 - 156ms/epoch - 11ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0239 - 154ms/epoch - 11ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0097 - val_loss: 0.0218 - 157ms/epoch - 11ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0254 - 154ms/epoch - 11ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0083 - val_loss: 0.0219 - 155ms/epoch - 11ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0086 - val_loss: 0.0219 - 158ms/epoch - 11ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0074 - val_loss: 0.0237 - 157ms/epoch - 11ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0094 - val_loss: 0.0200 - 155ms/epoch - 11ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0089 - val_loss: 0.0223 - 155ms/epoch - 11ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0072 - val_loss: 0.0232 - 154ms/epoch - 11ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0088 - val_loss: 0.0194 - 155ms/epoch - 11ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0079 - val_loss: 0.0202 - 155ms/epoch - 11ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0205 - 155ms/epoch - 11ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0276 - 156ms/epoch - 11ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0220 - 154ms/epoch - 11ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0068 - val_loss: 0.0210 - 156ms/epoch - 11ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0237 - 154ms/epoch - 11ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0221 - 155ms/epoch - 11ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0055 - val_loss: 0.0219 - 156ms/epoch - 11ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0070 - val_loss: 0.0187 - 154ms/epoch - 11ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0248 - 155ms/epoch - 11ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0194 - 154ms/epoch - 11ms/step

# %% [markdown]
# Visualizamos la perdida en las fases de entrenamiento.

# %%
visualizar_perdida(historico)

# %% [markdown]
# Realizamos la predicción de los 10 días siguientes. A su vez desnormalizamos los datos predichos y los reales.

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 288ms/step

# %% [markdown]
# Visualizamos una comparación entre los valores reales y los valores predichos.

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 533, número de casos predichos 571.4979
# 2022-03-20: número de casos reales 461, número de casos predichos 589.1559
# 2022-03-21: número de casos reales 948, número de casos predichos 595.5278
# 2022-03-22: número de casos reales 966, número de casos predichos 616.985
# 2022-03-23: número de casos reales 948, número de casos predichos 695.36066
# 2022-03-24: número de casos reales 790, número de casos predichos 764.9632
# 2022-03-25: número de casos reales 741, número de casos predichos 822.15784
# 2022-03-26: número de casos reales 428, número de casos predichos 860.3742
# 2022-03-27: número de casos reales 368, número de casos predichos 898.1888
# 2022-03-28: número de casos reales 528, número de casos predichos 902.1271

# %% [markdown]
# Graficamos la diferencia entre los valores de test y los predichos.

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %% [markdown]
# Calculamos la diferencia entre los valores reales y los valores predichos.

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([ -38.4979248 , -128.15588379,  352.472229  ,  349.01501465,
#         252.63934326,   25.0368042 ,  -81.15783691, -432.37420654,
#        -530.18878174, -374.1270752 ])

# %% [markdown]
# Por último, graficamos una parte del histórico de los datos de entrenamiento junto con los resultados del modelo de red neuronal y los valores predichos. A su vez mostramos un histograma con la diferencia entre dichos valores.

# %%
datos_train = datos_GranCanaria_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %% [markdown]
# Evaluamos los resultados con las métricas comentadas anteriormente.

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 94301.291441283
# Error absoluto medio (MAE) del modelo: 256.36651000976565
# Raíz del error cuadrático medio (RMSE) del modelo: 307.0851534042032
