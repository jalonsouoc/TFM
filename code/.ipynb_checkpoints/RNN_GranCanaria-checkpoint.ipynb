# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.legend()
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, indices, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color='blue')
    else:
        plt.plot(train_s.index, train_s, label='Train', color='blue')
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True, 
                   input_shape=(X_train.shape[1], X_train.shape[2]))) 
    modelo.add(LSTM(60, 
                   activation='relu',
                   return_sequences=True)) 
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False)) 
    modelo.add(Dense(units=1))
    modelo.compile(optimizer='adam', loss='mean_squared_error')
    modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
    
    return modelo
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_GranCanaria = datos[datos['isla'] == 'GRAN CANARIA']
datos_GranCanaria = datos_GranCanaria.set_index('fecha')

# %%
# Variables globales a utilizar en todo el proceso

variables_covid = ['pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19']      # Atributos para el análisis de las variables pandémicas
variables_atm = ['tmin', 'tmed', 'presMax']                              # Atributos para el análisis de las variables atmosféricas
variables = ['pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax']  # Atributos para el análisis de todas las variables


objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a agrupar 
isla = 'Gran Canaria'     # Isla a la que se está realziando el estudio
fechas = datos_GranCanaria.tail(dias_prediccion).index # Fechas de los días a predecir

# %%
datos_GranCanaria_uni = datos_GranCanaria[objetivo]
datos_GranCanaria_uni_arr = np.array(datos_GranCanaria_uni).reshape(-1, 1)

datos_GranCanaria_mult_covid = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19']]
datos_GranCanaria_mult_atm = datos_GranCanaria[[objetivo, 'tmin', 'tmed', 'presMax']]
datos_GranCanaria_mult_total = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax']]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_uni_scaled = scaler.fit_transform(datos_GranCanaria_uni_arr)

# %%
n_train = len(datos_GranCanaria_uni_scaled) - dias_prediccion


train = datos_GranCanaria_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_uni_scaled[n_train - dias_prediccion:len(datos_GranCanaria_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 74ms/step - loss: 0.0384 - val_loss: 0.0623
# Epoch 2/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.0331
# Epoch 3/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0193
# Epoch 4/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0223
# Epoch 5/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0110 - val_loss: 0.0218
# Epoch 6/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0093 - val_loss: 0.0250
# Epoch 7/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0090 - val_loss: 0.0201
# Epoch 8/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0083 - val_loss: 0.0184
# Epoch 9/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0080 - val_loss: 0.0193
# Epoch 10/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0177
# Epoch 11/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0167
# Epoch 12/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0074 - val_loss: 0.0166
# Epoch 13/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0160
# Epoch 14/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0160
# Epoch 15/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0154
# Epoch 16/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0153
# Epoch 17/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0150
# Epoch 18/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0149
# Epoch 19/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0142
# Epoch 20/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0068 - val_loss: 0.0151
# Epoch 21/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0146
# Epoch 22/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0141
# Epoch 23/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0143
# Epoch 24/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0150
# Epoch 25/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0058 - val_loss: 0.0144
# Epoch 26/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0140
# Epoch 27/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0146
# Epoch 28/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0151
# Epoch 29/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0150
# Epoch 30/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0147
# Epoch 31/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0050 - val_loss: 0.0151
# Epoch 32/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0167
# Epoch 33/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0199
# Epoch 34/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0146
# Epoch 35/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0153
# Epoch 36/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0179
# Epoch 37/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0144
# Epoch 38/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0165
# Epoch 39/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0138
# Epoch 40/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0168
# Epoch 41/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0148
# Epoch 42/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0160
# Epoch 43/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0151
# Epoch 44/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0156
# Epoch 45/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0166
# Epoch 46/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0046 - val_loss: 0.0149
# Epoch 47/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0164
# Epoch 48/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0148
# Epoch 49/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0044 - val_loss: 0.0163
# Epoch 50/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0045 - val_loss: 0.0142

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 328ms/step

# %%
y_pred
# Out:
# array([[484.76984],
#        [551.5123 ],
#        [615.0345 ],
#        [687.89276],
#        [744.6578 ],
#        [799.33234],
#        [863.40326],
#        [878.3829 ],
#        [839.01025],
#        [780.15985]], dtype=float32)

# %%
y_test
# Out:
# array([[533.],
#        [461.],
#        [948.],
#        [966.],
#        [948.],
#        [790.],
#        [741.],
#        [428.],
#        [368.],
#        [528.]])

# %%
isla = 'Gran Canaria'
fechas = datos_GranCanaria.tail(dias_prediccion).index
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 74342.59939718395
# Error absoluto medio (MAE) del modelo: 225.8446044921875
# Raíz del error cuadrático medio (RMSE) del modelo: 272.6583932271001

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
datos_GranCanaria_mult_covid = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19']]
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled = scaler.fit_transform(datos_GranCanaria_mult_covid)

# %%
# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_covid_scaled) - dias_prediccion


train = datos_GranCanaria_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_covid_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 69ms/step - loss: 0.0335 - val_loss: 0.0323
# Epoch 2/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0237 - val_loss: 0.0264
# Epoch 3/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0172 - val_loss: 0.0283
# Epoch 4/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0104 - val_loss: 0.0310
# Epoch 5/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0413
# Epoch 6/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0214
# Epoch 7/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0071 - val_loss: 0.0300
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0247
# Epoch 9/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0339
# Epoch 10/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0265
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0233
# Epoch 12/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0302
# Epoch 13/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0237
# Epoch 14/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0220
# Epoch 15/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0236
# Epoch 16/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0229
# Epoch 17/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0207
# Epoch 18/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0227
# Epoch 19/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0172
# Epoch 20/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0253
# Epoch 21/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0194
# Epoch 22/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0169
# Epoch 23/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0300
# Epoch 24/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0157
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0229
# Epoch 26/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0168
# Epoch 27/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0216
# Epoch 28/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0165
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0181
# Epoch 30/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0035 - val_loss: 0.0162
# Epoch 31/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0189
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0160
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0178
# Epoch 34/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0032 - val_loss: 0.0151
# Epoch 35/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0036 - val_loss: 0.0165
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0163
# Epoch 37/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0152
# Epoch 38/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0153
# Epoch 39/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0153
# Epoch 40/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0147
# Epoch 41/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0146
# Epoch 42/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0029 - val_loss: 0.0163
# Epoch 43/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0146
# Epoch 44/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0145
# Epoch 45/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0173
# Epoch 46/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0030 - val_loss: 0.0149
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0151
# Epoch 48/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0172
# Epoch 49/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0155
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0031 - val_loss: 0.0163

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 299ms/step

# %%
y_pred
# Out:
# array([[373.55978],
#        [397.6956 ],
#        [438.8702 ],
#        [511.62366],
#        [588.933  ],
#        [632.9766 ],
#        [638.24866],
#        [661.05457],
#        [694.87103],
#        [712.76135]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 85453.8797901365
# Error absoluto medio (MAE) del modelo: 254.97794494628906
# Raíz del error cuadrático medio (RMSE) del modelo: 292.3249558113992

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled = scaler.fit_transform(datos_GranCanaria_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_atm_scaled) - dias_prediccion


train = datos_GranCanaria_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_atm_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 71ms/step - loss: 0.0418 - val_loss: 0.0686
# Epoch 2/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0328 - val_loss: 0.0413
# Epoch 3/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0295 - val_loss: 0.0288
# Epoch 4/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0251 - val_loss: 0.0306
# Epoch 5/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0192 - val_loss: 0.0193
# Epoch 6/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0226
# Epoch 7/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0183
# Epoch 8/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0190
# Epoch 9/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0084 - val_loss: 0.0171
# Epoch 10/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0182
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0182
# Epoch 12/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0186
# Epoch 13/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0182
# Epoch 14/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0166
# Epoch 15/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0196
# Epoch 16/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0161
# Epoch 17/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0173
# Epoch 18/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0163
# Epoch 19/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0169
# Epoch 20/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0171
# Epoch 21/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0173
# Epoch 22/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0168
# Epoch 23/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0181
# Epoch 24/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0178
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0171
# Epoch 26/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0180
# Epoch 27/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0178
# Epoch 28/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0182
# Epoch 29/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0189
# Epoch 30/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0195
# Epoch 31/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0189
# Epoch 32/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0196
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0179
# Epoch 34/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0188
# Epoch 35/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0189
# Epoch 36/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0193
# Epoch 37/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0190
# Epoch 38/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0178
# Epoch 39/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0201
# Epoch 40/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0210
# Epoch 41/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0200
# Epoch 42/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0204
# Epoch 43/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0177
# Epoch 44/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0184
# Epoch 45/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0202
# Epoch 46/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0182
# Epoch 47/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0202
# Epoch 48/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0190
# Epoch 49/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0197
# Epoch 50/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0185

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 303ms/step

# %%
y_pred
# Out:
# array([[461.96893],
#        [475.55563],
#        [497.05276],
#        [539.2444 ],
#        [585.02203],
#        [626.7053 ],
#        [743.8407 ],
#        [828.1097 ],
#        [827.06476],
#        [759.8798 ]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 85453.8797901365
# Error absoluto medio (MAE) del modelo: 254.97794494628906
# Raíz del error cuadrático medio (RMSE) del modelo: 292.3249558113992

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled = scaler.fit_transform(datos_GranCanaria_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_total_scaled) - dias_prediccion


train = datos_GranCanaria_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_total_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 72ms/step - loss: 0.0357 - val_loss: 0.0397
# Epoch 2/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0271 - val_loss: 0.0360
# Epoch 3/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0204 - val_loss: 0.0366
# Epoch 4/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0116 - val_loss: 0.0345
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0657
# Epoch 6/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0274
# Epoch 7/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0398
# Epoch 8/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0314
# Epoch 9/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0067 - val_loss: 0.0306
# Epoch 10/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0331
# Epoch 11/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0056 - val_loss: 0.0289
# Epoch 12/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0382
# Epoch 13/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0231
# Epoch 14/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0303
# Epoch 15/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0225
# Epoch 16/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0237
# Epoch 17/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0037 - val_loss: 0.0207
# Epoch 18/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0164
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0195
# Epoch 20/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 0.0199
# Epoch 21/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0036 - val_loss: 0.0153
# Epoch 22/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0032 - val_loss: 0.0156
# Epoch 23/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0151
# Epoch 24/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0160
# Epoch 25/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0030 - val_loss: 0.0170
# Epoch 26/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 27/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0183
# Epoch 28/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0149
# Epoch 29/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0154
# Epoch 30/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0027 - val_loss: 0.0150
# Epoch 31/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0166
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0163
# Epoch 33/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0150
# Epoch 34/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 35/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0151
# Epoch 36/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0153
# Epoch 37/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0160
# Epoch 38/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0147
# Epoch 39/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0151
# Epoch 40/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0160
# Epoch 41/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0023 - val_loss: 0.0154
# Epoch 42/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0021 - val_loss: 0.0169
# Epoch 43/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0191
# Epoch 44/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0190
# Epoch 45/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0133
# Epoch 46/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0132
# Epoch 47/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0143
# Epoch 48/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0141
# Epoch 49/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0022 - val_loss: 0.0132
# Epoch 50/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0143

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 300ms/step

# %%
y_pred
# Out:
# array([[495.46558],
#        [517.5165 ],
#        [580.88916],
#        [719.1152 ],
#        [772.14667],
#        [808.74774],
#        [814.5034 ],
#        [833.7533 ],
#        [852.28613],
#        [869.0998 ]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,90,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 75252.19206193835
# Error absoluto medio (MAE) del modelo: 220.7290283203125
# Raíz del error cuadrático medio (RMSE) del modelo: 274.32132994344124
