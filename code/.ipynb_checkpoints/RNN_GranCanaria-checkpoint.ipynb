# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.legend()
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, indices, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color='blue')
    else:
        plt.plot(train_s.index, train_s, label='Train', color='blue')
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True, 
                   input_shape=(X_train.shape[1], X_train.shape[2]))) 
    modelo.add(LSTM(60, 
                   activation='relu',
                   return_sequences=True)) 
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False)) 
    modelo.add(Dense(units=1))
    modelo.compile(optimizer='adam', loss='mean_squared_error')
    modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
    
    return modelo
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_GranCanaria = datos[datos['isla'] == 'GRAN CANARIA']
datos_GranCanaria = datos_GranCanaria.set_index('fecha')

# %%
# Variables globales a utilizar en todo el proceso

variables_covid = ['pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']      # Atributos para el análisis de las variables pandémicas
variables_atm = ['tmin', 'tmed', 'presMax']                              # Atributos para el análisis de las variables atmosféricas
variables = ['pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax']  # Atributos para el análisis de todas las variables


objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a agrupar 
isla = 'Gran Canaria'     # Isla a la que se está realziando el estudio
fechas = datos_GranCanaria.tail(dias_prediccion).index # Fechas de los días a predecir

# %%
datos_GranCanaria_uni = datos_GranCanaria[objetivo]
datos_GranCanaria_uni_arr = np.array(datos_GranCanaria_uni).reshape(-1, 1)

datos_GranCanaria_mult_covid = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19']]
datos_GranCanaria_mult_atm = datos_GranCanaria[[objetivo, 'tmin', 'tmed', 'presMax']]
datos_GranCanaria_mult_total = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax']]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_uni_scaled = scaler.fit_transform(datos_GranCanaria_uni_arr)

# %%
n_train = len(datos_GranCanaria_uni_scaled) - dias_prediccion


train = datos_GranCanaria_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_uni_scaled[n_train - dias_prediccion:len(datos_GranCanaria_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 4s 81ms/step - loss: 0.0398 - val_loss: 0.0691
# Epoch 2/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0326 - val_loss: 0.0445
# Epoch 3/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0285 - val_loss: 0.0276
# Epoch 4/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0262 - val_loss: 0.0295
# Epoch 5/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0315
# Epoch 6/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0183 - val_loss: 0.0242
# Epoch 7/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0236
# Epoch 8/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0104 - val_loss: 0.0236
# Epoch 9/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0104 - val_loss: 0.0269
# Epoch 10/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0087 - val_loss: 0.0171
# Epoch 11/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0089 - val_loss: 0.0235
# Epoch 12/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0089 - val_loss: 0.0181
# Epoch 13/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0201
# Epoch 14/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0081 - val_loss: 0.0168
# Epoch 15/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077 - val_loss: 0.0175
# Epoch 16/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0078 - val_loss: 0.0166
# Epoch 17/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0158
# Epoch 18/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0165
# Epoch 19/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0075 - val_loss: 0.0157
# Epoch 20/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0075 - val_loss: 0.0158
# Epoch 21/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0158
# Epoch 22/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0073 - val_loss: 0.0155
# Epoch 23/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0156
# Epoch 24/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0155
# Epoch 25/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0072 - val_loss: 0.0154
# Epoch 26/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0153
# Epoch 27/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0072 - val_loss: 0.0153
# Epoch 28/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0154
# Epoch 29/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0071 - val_loss: 0.0152
# Epoch 30/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0153
# Epoch 31/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0150
# Epoch 32/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0152
# Epoch 33/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0069 - val_loss: 0.0149
# Epoch 34/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0069 - val_loss: 0.0149
# Epoch 35/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0152
# Epoch 36/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0150
# Epoch 37/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0151
# Epoch 38/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0154
# Epoch 39/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0066 - val_loss: 0.0149
# Epoch 40/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0066 - val_loss: 0.0149
# Epoch 41/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0153
# Epoch 42/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0155
# Epoch 43/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0151
# Epoch 44/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0064 - val_loss: 0.0152
# Epoch 45/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0147
# Epoch 46/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0063 - val_loss: 0.0150
# Epoch 47/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0150
# Epoch 48/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0148
# Epoch 49/50
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0149
# Epoch 50/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0148

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 336ms/step

# %%
y_pred
# Out:
# array([[512.41345],
#        [541.71655],
#        [570.1992 ],
#        [608.85205],
#        [667.1114 ],
#        [723.8874 ],
#        [765.0396 ],
#        [800.33026],
#        [817.65295],
#        [805.98083]], dtype=float32)

# %%
y_test
# Out:
# array([[533.],
#        [461.],
#        [948.],
#        [966.],
#        [948.],
#        [790.],
#        [741.],
#        [428.],
#        [368.],
#        [528.]])

# %%
isla = 'Gran Canaria'
fechas = datos_GranCanaria.tail(dias_prediccion).index
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 77916.51947665811
# Error absoluto medio (MAE) del modelo: 230.72567138671874
# Raíz del error cuadrático medio (RMSE) del modelo: 279.1353067540151

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
datos_GranCanaria_mult_covid = datos_GranCanaria[[objetivo, 'pcr_total', 'Urg_ingr', 'HPT_cv19', 'CCR_cv19']]
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled = scaler.fit_transform(datos_GranCanaria_mult_covid)

# %%
# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_covid_scaled) - dias_prediccion


train = datos_GranCanaria_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_covid_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 5s 88ms/step - loss: 0.0375 - val_loss: 0.0606
# Epoch 2/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0294 - val_loss: 0.0353
# Epoch 3/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0321
# Epoch 4/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0166 - val_loss: 0.0379
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0103 - val_loss: 0.0596
# Epoch 6/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0092 - val_loss: 0.0512
# Epoch 7/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 0.0401
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0387
# Epoch 9/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0463
# Epoch 10/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0397
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0433
# Epoch 12/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0333
# Epoch 13/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0408
# Epoch 14/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0346
# Epoch 15/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0338
# Epoch 16/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0333
# Epoch 17/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0325
# Epoch 18/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0292
# Epoch 19/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0284
# Epoch 20/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0254
# Epoch 21/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0256
# Epoch 22/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0223
# Epoch 23/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0253
# Epoch 24/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0168
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0201
# Epoch 26/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0163
# Epoch 27/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0223
# Epoch 28/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0191
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0150
# Epoch 30/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0218
# Epoch 31/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0039 - val_loss: 0.0170
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0172
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0035 - val_loss: 0.0154
# Epoch 34/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 0.0157
# Epoch 35/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0152
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0147
# Epoch 37/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0037 - val_loss: 0.0167
# Epoch 38/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0142
# Epoch 39/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0179
# Epoch 40/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0038 - val_loss: 0.0182
# Epoch 41/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0131
# Epoch 42/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0165
# Epoch 43/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0032 - val_loss: 0.0140
# Epoch 44/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0147
# Epoch 45/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0138
# Epoch 46/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0030 - val_loss: 0.0139
# Epoch 47/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0028 - val_loss: 0.0135
# Epoch 48/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0140
# Epoch 49/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0130
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0130

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 301ms/step

# %%
y_pred
# Out:
# array([[465.34186],
#        [483.76794],
#        [554.3396 ],
#        [675.7441 ],
#        [763.2649 ],
#        [817.3314 ],
#        [801.834  ],
#        [801.8199 ],
#        [795.5751 ],
#        [803.2269 ]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 68119.94659435861
# Error absoluto medio (MAE) del modelo: 212.38648071289063
# Raíz del error cuadrático medio (RMSE) del modelo: 260.9979819737283

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled = scaler.fit_transform(datos_GranCanaria_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_atm_scaled) - dias_prediccion


train = datos_GranCanaria_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_atm_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 4s 81ms/step - loss: 0.0408 - val_loss: 0.0669
# Epoch 2/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0326 - val_loss: 0.0398
# Epoch 3/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.0288
# Epoch 4/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0256 - val_loss: 0.0310
# Epoch 5/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0198 - val_loss: 0.0210
# Epoch 6/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0134 - val_loss: 0.0149
# Epoch 7/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0107 - val_loss: 0.0207
# Epoch 8/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0093 - val_loss: 0.0149
# Epoch 9/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0088 - val_loss: 0.0209
# Epoch 10/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0084 - val_loss: 0.0145
# Epoch 11/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.0208
# Epoch 12/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0078 - val_loss: 0.0173
# Epoch 13/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0075 - val_loss: 0.0187
# Epoch 14/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073 - val_loss: 0.0197
# Epoch 15/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0179
# Epoch 16/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0201
# Epoch 17/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0061 - val_loss: 0.0189
# Epoch 18/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0188
# Epoch 19/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0208
# Epoch 20/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0200
# Epoch 21/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0055 - val_loss: 0.0195
# Epoch 22/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0253
# Epoch 23/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0215
# Epoch 24/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0217
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0213
# Epoch 26/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0215
# Epoch 27/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0224
# Epoch 28/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0218
# Epoch 29/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0223
# Epoch 30/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0220
# Epoch 31/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0213
# Epoch 32/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0221
# Epoch 33/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056 - val_loss: 0.0229
# Epoch 34/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0215
# Epoch 35/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0041 - val_loss: 0.0210
# Epoch 36/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0217
# Epoch 37/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0221
# Epoch 38/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0217
# Epoch 39/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0042 - val_loss: 0.0230
# Epoch 40/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0044 - val_loss: 0.0215
# Epoch 41/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0208
# Epoch 42/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0039 - val_loss: 0.0231
# Epoch 43/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0209
# Epoch 44/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0196
# Epoch 45/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0040 - val_loss: 0.0200
# Epoch 46/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0038 - val_loss: 0.0235
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0040 - val_loss: 0.0203
# Epoch 48/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0201
# Epoch 49/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0037 - val_loss: 0.0187
# Epoch 50/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0041 - val_loss: 0.0233

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 303ms/step

# %%
y_pred
# Out:
# array([[ 669.15594],
#        [ 668.35345],
#        [ 689.91785],
#        [ 731.87256],
#        [ 735.3813 ],
#        [ 727.3346 ],
#        [ 906.8005 ],
#        [1041.1573 ],
#        [1006.11066],
#        [ 952.6442 ]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 122304.92844501809
# Error absoluto medio (MAE) del modelo: 295.27158203125
# Raíz del error cuadrático medio (RMSE) del modelo: 349.72121532017195

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled = scaler.fit_transform(datos_GranCanaria_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_GranCanaria_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_GranCanaria_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_GranCanaria_mult_total_scaled) - dias_prediccion


train = datos_GranCanaria_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_GranCanaria_mult_total_scaled[n_train - dias_prediccion:len(datos_GranCanaria_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 5s 106ms/step - loss: 0.0390 - val_loss: 0.0561
# Epoch 2/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0272 - val_loss: 0.0260
# Epoch 3/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0225 - val_loss: 0.0337
# Epoch 4/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0137 - val_loss: 0.0375
# Epoch 5/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0122 - val_loss: 0.0512
# Epoch 6/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0092 - val_loss: 0.0279
# Epoch 7/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0082 - val_loss: 0.0434
# Epoch 8/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0086 - val_loss: 0.0304
# Epoch 9/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0072 - val_loss: 0.0360
# Epoch 10/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0321
# Epoch 11/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 0.0267
# Epoch 12/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0054 - val_loss: 0.0324
# Epoch 13/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0235
# Epoch 14/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0253
# Epoch 15/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0239
# Epoch 16/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0195
# Epoch 17/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0040 - val_loss: 0.0241
# Epoch 18/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0165
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0036 - val_loss: 0.0165
# Epoch 20/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0183
# Epoch 21/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0164
# Epoch 22/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0137
# Epoch 23/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0152
# Epoch 24/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0151
# Epoch 25/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0133
# Epoch 26/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0137
# Epoch 27/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0149
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0140
# Epoch 29/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0133
# Epoch 30/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0132
# Epoch 31/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0136
# Epoch 32/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 0.0131
# Epoch 33/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0137
# Epoch 34/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0125
# Epoch 35/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0133
# Epoch 36/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0132
# Epoch 37/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0029 - val_loss: 0.0129
# Epoch 38/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0128
# Epoch 39/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0129
# Epoch 40/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0121
# Epoch 41/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0127
# Epoch 42/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0127
# Epoch 43/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0126
# Epoch 44/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0129
# Epoch 45/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0124
# Epoch 46/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0129
# Epoch 47/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0133
# Epoch 48/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 0.0114
# Epoch 49/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0131
# Epoch 50/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0119

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 295ms/step

# %%
y_pred
# Out:
# array([[417.50272],
#        [413.32645],
#        [496.0695 ],
#        [684.5121 ],
#        [747.7834 ],
#        [748.07947],
#        [755.5677 ],
#        [749.4022 ],
#        [739.7946 ],
#        [732.6071 ]], dtype=float32)

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_GranCanaria_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,90,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 62453.99621073259
# Error absoluto medio (MAE) del modelo: 205.10980529785155
# Raíz del error cuadrático medio (RMSE) del modelo: 249.90797548444226
