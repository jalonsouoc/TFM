# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de La Palma

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.legend()
    plt.show()
    
def visualizar_historico(train, test, pred, variable, dias_historico, indices, tit):
    train_s = train.iloc[len(train) - dias_historico:]
    color_isla = 'cyan'
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=60)

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True, 
                   input_shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
    
    return modelo
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)
datos_LaPalma = datos[datos['isla'] == 'LA PALMA']

datos_LaPalma = datos_LaPalma.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'La Palma'         # Isla a la que se está realziando el estudio
fechas = datos_LaPalma.tail(dias_prediccion).index # Fechas de los días a predecir

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_LaPalma_uni = datos_LaPalma[objetivo]
datos_LaPalma_uni_arr = np.array(datos_LaPalma_uni).reshape(-1, 1)

datos_LaPalma_mult_covid = datos_LaPalma[variables_covid]
datos_LaPalma_mult_atm = datos_LaPalma[variables_atm]
datos_LaPalma_mult_total = datos_LaPalma[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_uni_scaled = scaler.fit_transform(datos_LaPalma_uni_arr)

# %%
n_train = len(datos_LaPalma_uni_scaled) - dias_prediccion


train = datos_LaPalma_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_uni_scaled[n_train - dias_prediccion:len(datos_LaPalma_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 4s 84ms/step - loss: 0.0248 - val_loss: 0.0210
# Epoch 2/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0231 - val_loss: 0.0200
# Epoch 3/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.0194
# Epoch 4/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0214 - val_loss: 0.0177
# Epoch 5/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0207 - val_loss: 0.0169
# Epoch 6/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.0153
# Epoch 7/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0196 - val_loss: 0.0155
# Epoch 8/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0185 - val_loss: 0.0151
# Epoch 9/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0179 - val_loss: 0.0142
# Epoch 10/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0171 - val_loss: 0.0129
# Epoch 11/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0165 - val_loss: 0.0127
# Epoch 12/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0160 - val_loss: 0.0119
# Epoch 13/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0148 - val_loss: 0.0113
# Epoch 14/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0144 - val_loss: 0.0096
# Epoch 15/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0136 - val_loss: 0.0098
# Epoch 16/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0128 - val_loss: 0.0092
# Epoch 17/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.0087
# Epoch 18/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0085
# Epoch 19/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0089
# Epoch 20/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0105 - val_loss: 0.0095
# Epoch 21/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0107 - val_loss: 0.0086
# Epoch 22/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 23/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0097 - val_loss: 0.0092
# Epoch 24/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0090 - val_loss: 0.0086
# Epoch 25/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0095 - val_loss: 0.0080
# Epoch 26/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 27/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0088 - val_loss: 0.0086
# Epoch 28/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 30/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 31/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0092
# Epoch 32/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 0.0073
# Epoch 33/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0095
# Epoch 34/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 35/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 36/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0067 - val_loss: 0.0067
# Epoch 37/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 38/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 39/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 40/50
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 41/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 42/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 43/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 44/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 45/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 46/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0068
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 48/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 49/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0087
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0063 - val_loss: 0.0068

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 464ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 90.13086
# 2022-03-20: número de casos reales 30, número de casos predichos 86.843575
# 2022-03-21: número de casos reales 127, número de casos predichos 86.873344
# 2022-03-22: número de casos reales 90, número de casos predichos 85.30015
# 2022-03-23: número de casos reales 106, número de casos predichos 94.125465
# 2022-03-24: número de casos reales 70, número de casos predichos 109.63634
# 2022-03-25: número de casos reales 89, número de casos predichos 102.54374
# 2022-03-26: número de casos reales 26, número de casos predichos 97.20194
# 2022-03-27: número de casos reales 15, número de casos predichos 94.45856
# 2022-03-28: número de casos reales 63, número de casos predichos 88.584

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaPalma_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 2092.4881873893437
# Error absoluto medio (MAE) del modelo: 38.91000518798828
# Raíz del error cuadrático medio (RMSE) del modelo: 45.74372292882755

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_covid_scaled = scaler.fit_transform(datos_LaPalma_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_covid_scaled) - dias_prediccion


train = datos_LaPalma_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_covid_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 6s 123ms/step - loss: 0.0256 - val_loss: 0.0190
# Epoch 2/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0236 - val_loss: 0.0171
# Epoch 3/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0221 - val_loss: 0.0168
# Epoch 4/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0209 - val_loss: 0.0157
# Epoch 5/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0196 - val_loss: 0.0154
# Epoch 6/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0187 - val_loss: 0.0148
# Epoch 7/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0176 - val_loss: 0.0158
# Epoch 8/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0158
# Epoch 9/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0157 - val_loss: 0.0186
# Epoch 10/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0151 - val_loss: 0.0151
# Epoch 11/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0147 - val_loss: 0.0175
# Epoch 12/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0143 - val_loss: 0.0158
# Epoch 13/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0139 - val_loss: 0.0176
# Epoch 14/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0135 - val_loss: 0.0139
# Epoch 15/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0124 - val_loss: 0.0151
# Epoch 16/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0129
# Epoch 17/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0121 - val_loss: 0.0148
# Epoch 18/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0131
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0118
# Epoch 20/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 21/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0106 - val_loss: 0.0090
# Epoch 22/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0103 - val_loss: 0.0132
# Epoch 23/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.0110
# Epoch 24/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0123
# Epoch 25/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0111
# Epoch 26/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0106
# Epoch 27/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0085
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0082 - val_loss: 0.0126
# Epoch 29/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0105
# Epoch 30/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 31/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0081 - val_loss: 0.0078
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0086
# Epoch 33/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0103
# Epoch 34/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0077
# Epoch 35/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0078 - val_loss: 0.0119
# Epoch 36/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0126
# Epoch 37/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 38/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0068 - val_loss: 0.0118
# Epoch 39/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 40/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0097
# Epoch 41/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0114
# Epoch 42/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0070 - val_loss: 0.0087
# Epoch 43/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 44/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 45/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0067 - val_loss: 0.0086
# Epoch 46/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0063 - val_loss: 0.0105
# Epoch 47/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 48/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 49/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 50/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0059 - val_loss: 0.0071

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 1s 565ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 84.05677
# 2022-03-20: número de casos reales 30, número de casos predichos 90.64146
# 2022-03-21: número de casos reales 127, número de casos predichos 87.04468
# 2022-03-22: número de casos reales 90, número de casos predichos 86.75145
# 2022-03-23: número de casos reales 106, número de casos predichos 95.67679
# 2022-03-24: número de casos reales 70, número de casos predichos 111.17031
# 2022-03-25: número de casos reales 89, número de casos predichos 105.64492
# 2022-03-26: número de casos reales 26, número de casos predichos 97.50883
# 2022-03-27: número de casos reales 15, número de casos predichos 95.93146
# 2022-03-28: número de casos reales 63, número de casos predichos 94.19165

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaPalma_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 2160.3860782567936
# Error absoluto medio (MAE) del modelo: 39.567247772216795
# Raíz del error cuadrático medio (RMSE) del modelo: 46.47995350962384

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_atm_scaled = scaler.fit_transform(datos_LaPalma_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_atm_scaled) - dias_prediccion


train = datos_LaPalma_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_atm_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 7s 181ms/step - loss: 0.0289 - val_loss: 0.0242
# Epoch 2/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0272 - val_loss: 0.0232
# Epoch 3/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0260 - val_loss: 0.0212
# Epoch 4/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0249 - val_loss: 0.0206
# Epoch 5/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0239 - val_loss: 0.0200
# Epoch 6/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0226 - val_loss: 0.0176
# Epoch 7/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0219 - val_loss: 0.0162
# Epoch 8/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0209 - val_loss: 0.0157
# Epoch 9/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0201 - val_loss: 0.0148
# Epoch 10/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0195 - val_loss: 0.0146
# Epoch 11/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0186 - val_loss: 0.0138
# Epoch 12/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0176 - val_loss: 0.0137
# Epoch 13/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0167 - val_loss: 0.0128
# Epoch 14/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0158 - val_loss: 0.0126
# Epoch 15/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0151 - val_loss: 0.0120
# Epoch 16/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0142 - val_loss: 0.0127
# Epoch 17/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0137 - val_loss: 0.0113
# Epoch 18/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0136 - val_loss: 0.0108
# Epoch 19/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0129 - val_loss: 0.0105
# Epoch 20/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0125 - val_loss: 0.0110
# Epoch 21/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0120
# Epoch 22/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 23/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0118 - val_loss: 0.0110
# Epoch 24/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0111 - val_loss: 0.0088
# Epoch 25/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0109 - val_loss: 0.0105
# Epoch 26/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0100 - val_loss: 0.0118
# Epoch 27/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0104 - val_loss: 0.0092
# Epoch 28/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0095 - val_loss: 0.0130
# Epoch 29/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0101 - val_loss: 0.0078
# Epoch 30/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0096 - val_loss: 0.0074
# Epoch 31/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 0.0096
# Epoch 32/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 33/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 34/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 35/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0079 - val_loss: 0.0069
# Epoch 36/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0087 - val_loss: 0.0075
# Epoch 37/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 38/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0076
# Epoch 39/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0064
# Epoch 40/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 41/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0071 - val_loss: 0.0083
# Epoch 42/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 43/50
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0075 - val_loss: 0.0068
# Epoch 44/50
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0069 - val_loss: 0.0103
# Epoch 45/50
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0072
# Epoch 46/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0065 - val_loss: 0.0085
# Epoch 47/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0085
# Epoch 48/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0068 - val_loss: 0.0069
# Epoch 49/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 50/50
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0059

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 340ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 83.24777
# 2022-03-20: número de casos reales 30, número de casos predichos 80.3267
# 2022-03-21: número de casos reales 127, número de casos predichos 80.79666
# 2022-03-22: número de casos reales 90, número de casos predichos 79.58479
# 2022-03-23: número de casos reales 106, número de casos predichos 87.75004
# 2022-03-24: número de casos reales 70, número de casos predichos 100.32302
# 2022-03-25: número de casos reales 89, número de casos predichos 93.06683
# 2022-03-26: número de casos reales 26, número de casos predichos 87.840706
# 2022-03-27: número de casos reales 15, número de casos predichos 84.48233
# 2022-03-28: número de casos reales 63, número de casos predichos 77.96942

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaPalma_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 1646.1625768273138
# Error absoluto medio (MAE) del modelo: 34.51252899169922
# Raíz del error cuadrático medio (RMSE) del modelo: 40.57292911323157

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_total_scaled = scaler.fit_transform(datos_LaPalma_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_total_scaled) - dias_prediccion


train = datos_LaPalma_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_total_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 8s 243ms/step - loss: 0.0333 - val_loss: 0.0273
# Epoch 2/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0305 - val_loss: 0.0240
# Epoch 3/50
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0285 - val_loss: 0.0230
# Epoch 4/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0271 - val_loss: 0.0222
# Epoch 5/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0255 - val_loss: 0.0222
# Epoch 6/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0243 - val_loss: 0.0257
# Epoch 7/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0232 - val_loss: 0.0213
# Epoch 8/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0224 - val_loss: 0.0245
# Epoch 9/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0209 - val_loss: 0.0246
# Epoch 10/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0205 - val_loss: 0.0215
# Epoch 11/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0186 - val_loss: 0.0250
# Epoch 12/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0192 - val_loss: 0.0230
# Epoch 13/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0182 - val_loss: 0.0246
# Epoch 14/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0170 - val_loss: 0.0221
# Epoch 15/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0164 - val_loss: 0.0227
# Epoch 16/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0163 - val_loss: 0.0154
# Epoch 17/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0155 - val_loss: 0.0227
# Epoch 18/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0145 - val_loss: 0.0199
# Epoch 19/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0143 - val_loss: 0.0204
# Epoch 20/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0132 - val_loss: 0.0142
# Epoch 21/50
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0134 - val_loss: 0.0166
# Epoch 22/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0129 - val_loss: 0.0183
# Epoch 23/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0125 - val_loss: 0.0199
# Epoch 24/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0124 - val_loss: 0.0156
# Epoch 25/50
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0114 - val_loss: 0.0153
# Epoch 26/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0110 - val_loss: 0.0175
# Epoch 27/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0110 - val_loss: 0.0123
# Epoch 28/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0114 - val_loss: 0.0153
# Epoch 29/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0100 - val_loss: 0.0100
# Epoch 30/50
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0101 - val_loss: 0.0107
# Epoch 31/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0095 - val_loss: 0.0173
# Epoch 32/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0095 - val_loss: 0.0104
# Epoch 33/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0083 - val_loss: 0.0229
# Epoch 34/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0090 - val_loss: 0.0111
# Epoch 35/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0083 - val_loss: 0.0144
# Epoch 36/50
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0085 - val_loss: 0.0098
# Epoch 37/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0083 - val_loss: 0.0138
# Epoch 38/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0077 - val_loss: 0.0128
# Epoch 39/50
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0077 - val_loss: 0.0218
# Epoch 40/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0073 - val_loss: 0.0089
# Epoch 41/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0079 - val_loss: 0.0103
# Epoch 42/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0071 - val_loss: 0.0090
# Epoch 43/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0070 - val_loss: 0.0166
# Epoch 44/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0065 - val_loss: 0.0149
# Epoch 45/50
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0066 - val_loss: 0.0108
# Epoch 46/50
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 0.0106
# Epoch 47/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0066 - val_loss: 0.0088
# Epoch 48/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 49/50
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 50/50
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0061 - val_loss: 0.0082

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 347ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 97.336334
# 2022-03-20: número de casos reales 30, número de casos predichos 103.02291
# 2022-03-21: número de casos reales 127, número de casos predichos 96.3748
# 2022-03-22: número de casos reales 90, número de casos predichos 92.52979
# 2022-03-23: número de casos reales 106, número de casos predichos 102.11207
# 2022-03-24: número de casos reales 70, número de casos predichos 119.01118
# 2022-03-25: número de casos reales 89, número de casos predichos 112.35192
# 2022-03-26: número de casos reales 26, número de casos predichos 99.8187
# 2022-03-27: número de casos reales 15, número de casos predichos 94.89305
# 2022-03-28: número de casos reales 63, número de casos predichos 89.99429

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
datos_train = datos_LaPalma_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,100,fechas,tit)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 2464.4728781578947
# Error absoluto medio (MAE) del modelo: 41.64713134765625
# Raíz del error cuadrático medio (RMSE) del modelo: 49.643457556438335
