# %% [markdown]
# # Estudio de la evolución de la pandemia por el modelo de red neuronal recurrente para la isla de La Palma

# %%
# Carga inicial de librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Input
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras import regularizers

# %%
def get_X_y(datos, dias):
    
    X, y = [], []
    
    for i in range(len(datos) - dias):
        X.append(datos[i:(i + dias), :])
        y.append(datos[i + dias, 0])
        
    return np.array(X), np.array(y)

def visualizar_pred_test(y_test, y_pred, fechas, tit):
    #plt.figure(figsize=(16, 6))
    plt.plot(fechas, y_test, label='Test', color='green')
    plt.plot(fechas, y_pred, label='Predicciones', color='orange')
    plt.xticks(rotation=60)
    plt.xlabel('Fechas')
    plt.ylabel('Número de casos de COVID')
    plt.title(tit)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.legend()
    plt.show()
    
def visualizar_historico(train, y_test, y_pred, variable, dias_historico, indices, tit, color, dif):
    train_s = train.iloc[len(train) - dias_historico:]
    
    plt.figure(figsize=(10, 6))
    if variable != '':
        plt.plot(train_s.index, train_s[variable], label='Train', color=color_isla)
    else:
        plt.plot(train_s.index, train_s, label='Train', color=color_isla)
    plt.plot(indices, y_test, label='Test', color='green')
    plt.plot(indices, y_pred, label='Predicciones', color='orange')
    plt.bar(indices, dif, width=0.5, color='black', alpha=0.2, align='edge', label='Diferencia')
    
    plt.xticks(np.arange(0, len(train_s.index)  + len(indices), step=5),   train_s.index.union(indices)[::5], rotation=70)
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')

    plt.legend()
    plt.title(tit)
    plt.xlabel('Fecha')
    plt.ylabel('Número de casos de COVID')
    plt.show()
    
def obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test):
    modelo = Sequential()
    neurons= X_train.shape[1]
    modelo.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
    modelo.add(LSTM(X_train.shape[1] * X_train.shape[2], 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(50, 
                   activation='relu',
                   return_sequences=True))
    modelo.add(Dropout(0.2))
    modelo.add(LSTM(25, 
                   activation='relu',
                   return_sequences=False))
    modelo.add(Dropout(0.2))
    #modelo.add(Dense(5, activation='relu'))
    modelo.add(Dense(units=1, kernel_regularizer=regularizers.l2(0.01)))
    modelo.compile(optimizer='rmsprop', loss='mean_squared_error')
    historico = modelo.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=40, batch_size=32, verbose=2)
    
    return modelo, historico
    
def obtener_errores(y_true, y_pred):
    ''' Método que devuelvo los errores:
            * MAE: Error absoluto medio
            * MSE: Error cuadrático medio
            * RMSE: Raíz del error cuadrático medio
    
    Args:
        y_true (Serie): Valores reales del conjunto de test
        y_pred (Serie): Valores predichos por el modelo
    Return:
        mae(float): Error absoluto medio
        mse(float): Error cuadrático medio
        rmse(float): Raíz del error cuadrático medio
    '''
    
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    
    return mae, mse, rmse

def visualizar_resultados_texto(y_test, y_pred, fechas):
    for i in range(len(y_test)):
        print(str(fechas[i]) + ': número de casos reales ' + str(int(y_test[i][0])) + ', número de casos predichos ' + str(y_pred[i][0]))
        
def visualizar_perdida(historico):
    plt.plot(historico.history['loss'], label='train')
    plt.plot(historico.history['val_loss'], label='test')
    plt.gca().set_facecolor('lightgrey')
    plt.grid(True, linestyle='--', linewidth=0.5, color='white')
    plt.title('Pérdida del modelo')
    plt.legend()
    plt.show()

# %%
# Cargamos los datos de las estaciones de cada una de las islas
datos = pd.read_csv('../data/Final/datos_final.csv', header=0)

# Obtenemos los datos de la isla a la que se le va a realizar el estudio
datos_LaPalma = datos[datos['isla'] == 'LA PALMA']

datos_LaPalma = datos_LaPalma.sort_values(by='fecha') # Ordenamos por fecha por si los datos devueltos no estuvieran en orden
datos_LaPalma = datos_LaPalma.set_index('fecha') # Asignamos la fecha como índice

# %%
# Variables globales a utilizar en todo el proceso

objetivo = 'numero_casos' # Variable objetivo
dias_prediccion = 10      # días a predecir y a agrupar para cada predicción
isla = 'La Palma'         # Isla a la que se está realziando el estudio
fechas = datos_LaPalma.tail(dias_prediccion).index # Fechas de los días a predecir
color_isla = 'darkcyan' # Color de la isla en las visualizaciones
n_dias_train_vis = 100    # Número de días del conjunto de train a visualizar en el conjunto de train

variables_covid = [objetivo, 'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19']    # Atributos para el análisis de las variables pandémicas
variables_atm = [objetivo, 'tmin', 'tmed', 'presMax']                            # Atributos para el análisis de las variables atmosféricas
variables = [objetivo,'pcr_total', 'Urg_cv', 'HPT_cv19', 'CCR_cv19','tmin', 'tmed', 'presMax'] # Atributos para el análisis de todas las variables

# %%
# Cargamos los datos de cada estudio con sus atributos correspondientes
datos_LaPalma_uni = datos_LaPalma[objetivo]
datos_LaPalma_uni_arr = np.array(datos_LaPalma_uni).reshape(-1, 1)

datos_LaPalma_mult_covid = datos_LaPalma[variables_covid]
datos_LaPalma_mult_atm = datos_LaPalma[variables_atm]
datos_LaPalma_mult_total = datos_LaPalma[variables]

# %% [markdown]
# # Red Neuronal Recurrente univariable

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_uni_scaled = scaler.fit_transform(datos_LaPalma_uni_arr)

# %%
n_train = len(datos_LaPalma_uni_scaled) - dias_prediccion


train = datos_LaPalma_uni_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_uni_scaled[n_train - dias_prediccion:len(datos_LaPalma_uni_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0307 - val_loss: 0.0255 - 3s/epoch - 214ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0275 - val_loss: 0.0233 - 121ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0255 - val_loss: 0.0212 - 120ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0234 - val_loss: 0.0190 - 121ms/epoch - 9ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0209 - val_loss: 0.0169 - 121ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0188 - val_loss: 0.0153 - 120ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0172 - val_loss: 0.0150 - 123ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0155 - val_loss: 0.0144 - 121ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0148 - val_loss: 0.0148 - 122ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0143 - val_loss: 0.0124 - 121ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0140 - 119ms/epoch - 8ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0115 - val_loss: 0.0124 - 121ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0095 - 120ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0114 - val_loss: 0.0106 - 121ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0091 - 121ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0100 - val_loss: 0.0093 - 121ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0093 - val_loss: 0.0075 - 120ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0085 - val_loss: 0.0075 - 122ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0085 - val_loss: 0.0068 - 122ms/epoch - 9ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0080 - val_loss: 0.0066 - 119ms/epoch - 8ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0082 - val_loss: 0.0062 - 121ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0074 - val_loss: 0.0063 - 122ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0085 - 120ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0058 - 120ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0070 - val_loss: 0.0063 - 120ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0077 - 122ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0061 - 121ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0055 - 122ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0064 - 121ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0063 - 121ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0054 - 121ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0052 - 120ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0061 - 120ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0055 - val_loss: 0.0066 - 121ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0064 - val_loss: 0.0052 - 121ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0058 - val_loss: 0.0064 - 120ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0052 - val_loss: 0.0080 - 120ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0064 - val_loss: 0.0060 - 120ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0061 - 122ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0052 - 119ms/epoch - 8ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler.inverse_transform(test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 316ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 80.613785
# 2022-03-20: número de casos reales 30, número de casos predichos 77.93152
# 2022-03-21: número de casos reales 127, número de casos predichos 77.93731
# 2022-03-22: número de casos reales 90, número de casos predichos 76.84552
# 2022-03-23: número de casos reales 106, número de casos predichos 84.11594
# 2022-03-24: número de casos reales 70, número de casos predichos 96.56542
# 2022-03-25: número de casos reales 89, número de casos predichos 91.03547
# 2022-03-26: número de casos reales 26, número de casos predichos 86.627396
# 2022-03-27: número de casos reales 15, número de casos predichos 84.18947
# 2022-03-28: número de casos reales 63, número de casos predichos 79.21173

# %%
tit = 'Red Neuronal Recurrente univariable para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-36.61378479, -47.93151855,  49.06269073,  13.15447998,
#         21.88406372, -26.56542206,  -2.03546906, -60.62739563,
#        -69.18946838, -16.21173096])

# %%
datos_train = datos_LaPalma_uni.iloc[:n_train]
visualizar_historico(datos_train,y_test,y_pred,'',n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 1613.2648558359535
# Error absoluto medio (MAE) del modelo: 34.32760238647461
# Raíz del error cuadrático medio (RMSE) del modelo: 40.16546845034866

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables de pandemia

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_covid_scaled = scaler.fit_transform(datos_LaPalma_mult_covid)


# Escalador para las predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_covid_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_covid[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_covid_scaled) - dias_prediccion


train = datos_LaPalma_mult_covid_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_covid_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_covid_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0313 - val_loss: 0.0264 - 3s/epoch - 215ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0281 - val_loss: 0.0231 - 134ms/epoch - 10ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0255 - val_loss: 0.0206 - 134ms/epoch - 10ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0237 - val_loss: 0.0181 - 134ms/epoch - 10ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0215 - val_loss: 0.0169 - 133ms/epoch - 10ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0200 - val_loss: 0.0164 - 133ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0185 - val_loss: 0.0179 - 132ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0169 - val_loss: 0.0151 - 132ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0153 - val_loss: 0.0145 - 133ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0155 - 130ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0128 - 131ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0130 - val_loss: 0.0109 - 133ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0129 - val_loss: 0.0101 - 131ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0127 - val_loss: 0.0090 - 131ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0116 - val_loss: 0.0094 - 131ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0099 - val_loss: 0.0180 - 131ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0081 - 132ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0089 - val_loss: 0.0076 - 133ms/epoch - 10ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0092 - val_loss: 0.0066 - 131ms/epoch - 9ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0089 - val_loss: 0.0063 - 131ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0080 - val_loss: 0.0063 - 135ms/epoch - 10ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0074 - val_loss: 0.0087 - 133ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0080 - val_loss: 0.0054 - 132ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0075 - val_loss: 0.0080 - 133ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0065 - 134ms/epoch - 10ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0063 - 134ms/epoch - 10ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0060 - 131ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0056 - 132ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0055 - 134ms/epoch - 10ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0065 - val_loss: 0.0055 - 132ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0056 - val_loss: 0.0043 - 132ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0060 - val_loss: 0.0049 - 133ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0056 - val_loss: 0.0045 - 132ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0055 - val_loss: 0.0041 - 131ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0056 - val_loss: 0.0051 - 131ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0047 - 133ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0069 - 132ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0051 - val_loss: 0.0043 - 132ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0057 - val_loss: 0.0042 - 133ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0054 - val_loss: 0.0047 - 133ms/epoch - 10ms/step

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-80.54008295, -80.56353353, -80.40105447, -80.46303102,
#        -80.43623035, -80.49653186, -80.46470606, -80.5702337 ,
#        -80.58865916, -80.50825715, -77.85781671, -77.8812673 ,
#        -77.71878824, -77.78076479, -77.75396412, -77.81426562,
#        -77.78243983, -77.88796747, -77.90639293, -77.82599092,
#        -77.86360742, -77.88705801, -77.72457895, -77.7865555 ,
#        -77.75975483, -77.82005633, -77.78823054, -77.89375818,
#        -77.91218364, -77.83178163, -76.77181818, -76.79526876,
#        -76.6327897 , -76.69476625, -76.66796558, -76.72826709,
#        -76.69644129, -76.80196893, -76.82039439, -76.73999238,
#        -84.04223444, -84.06568502, -83.90320596, -83.96518251,
#        -83.93838184, -83.99868335, -83.96685755, -84.07238519,
#        -84.09081065, -84.01040864, -96.49172022, -96.5151708 ,
#        -96.35269174, -96.41466829, -96.38786762, -96.44816913,
#        -96.41634333, -96.52187097, -96.54029643, -96.45989442,
#        -90.96176721, -90.9852178 , -90.82273874, -90.88471529,
#        -90.85791462, -90.91821612, -90.88639033, -90.99191797,
#        -91.01034343, -90.92994142, -86.55369379, -86.57714437,
#        -86.41466531, -86.47664186, -86.44984119, -86.5101427 ,
#        -86.4783169 , -86.58384454, -86.60227   , -86.52186799,
#        -84.11576654, -84.13921713, -83.97673807, -84.03871461,
#        -84.01191394, -84.07221545, -84.04038966, -84.1459173 ,
#        -84.16434276, -84.08394075, -79.13802911, -79.1614797 ,
#        -78.99900064, -79.06097719, -79.03417652, -79.09447803,
#        -79.06265223, -79.16817987, -79.18660533, -79.10620332])

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 286ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 77.51959
# 2022-03-20: número de casos reales 30, número de casos predichos 82.17478
# 2022-03-21: número de casos reales 127, número de casos predichos 79.79399
# 2022-03-22: número de casos reales 90, número de casos predichos 79.17311
# 2022-03-23: número de casos reales 106, número de casos predichos 85.866264
# 2022-03-24: número de casos reales 70, número de casos predichos 98.16421
# 2022-03-25: número de casos reales 89, número de casos predichos 90.59452
# 2022-03-26: número de casos reales 26, número de casos predichos 80.1332
# 2022-03-27: número de casos reales 15, número de casos predichos 77.0495
# 2022-03-28: número de casos reales 63, número de casos predichos 75.92168

# %%
tit = 'Red Neuronal Recurrente multivariable con variables pandémicas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-33.51959229, -52.1747818 ,  47.20600891,  10.82688904,
#         20.13373566, -28.16420746,  -1.59452057, -54.1332016 ,
#        -62.04949951, -12.92167664])

# %%
datos_train = datos_LaPalma_mult_covid.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 1434.0045747540019
# Error absoluto medio (MAE) del modelo: 32.27241134643555
# Raíz del error cuadrático medio (RMSE) del modelo: 37.86825286112368

# %% [markdown]
# # Red Neuronal Recurrente multivariable con variables atmosféricas

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_atm_scaled = scaler.fit_transform(datos_LaPalma_mult_atm)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_atm_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_atm[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_atm_scaled) - dias_prediccion


train = datos_LaPalma_mult_atm_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_atm_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_atm_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0298 - val_loss: 0.0230 - 3s/epoch - 209ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0272 - val_loss: 0.0224 - 132ms/epoch - 9ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0253 - val_loss: 0.0190 - 127ms/epoch - 9ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0232 - val_loss: 0.0170 - 127ms/epoch - 9ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0214 - val_loss: 0.0159 - 127ms/epoch - 9ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0193 - val_loss: 0.0154 - 127ms/epoch - 9ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0178 - val_loss: 0.0140 - 127ms/epoch - 9ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0165 - val_loss: 0.0131 - 128ms/epoch - 9ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0155 - val_loss: 0.0127 - 127ms/epoch - 9ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0145 - val_loss: 0.0148 - 128ms/epoch - 9ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0128 - val_loss: 0.0104 - 127ms/epoch - 9ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0120 - val_loss: 0.0117 - 129ms/epoch - 9ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0110 - val_loss: 0.0103 - 128ms/epoch - 9ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0109 - val_loss: 0.0106 - 126ms/epoch - 9ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0110 - 128ms/epoch - 9ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0094 - val_loss: 0.0077 - 131ms/epoch - 9ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0241 - 126ms/epoch - 9ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0087 - val_loss: 0.0108 - 127ms/epoch - 9ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0078 - val_loss: 0.0187 - 135ms/epoch - 10ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0087 - val_loss: 0.0091 - 128ms/epoch - 9ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0082 - val_loss: 0.0066 - 128ms/epoch - 9ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0084 - val_loss: 0.0086 - 128ms/epoch - 9ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0076 - val_loss: 0.0081 - 127ms/epoch - 9ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0077 - val_loss: 0.0092 - 128ms/epoch - 9ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0113 - 127ms/epoch - 9ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0054 - 127ms/epoch - 9ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0068 - val_loss: 0.0061 - 128ms/epoch - 9ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0068 - val_loss: 0.0082 - 130ms/epoch - 9ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0152 - 126ms/epoch - 9ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0068 - val_loss: 0.0100 - 126ms/epoch - 9ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0064 - val_loss: 0.0110 - 128ms/epoch - 9ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0101 - 129ms/epoch - 9ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0082 - 126ms/epoch - 9ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0066 - val_loss: 0.0070 - 126ms/epoch - 9ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0055 - 128ms/epoch - 9ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0060 - val_loss: 0.0070 - 127ms/epoch - 9ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0074 - 126ms/epoch - 9ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0054 - val_loss: 0.0058 - 127ms/epoch - 9ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0050 - val_loss: 0.0044 - 126ms/epoch - 9ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0060 - val_loss: 0.0088 - 129ms/epoch - 9ms/step

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-77.44589044, -77.46934103, -77.30686197, -77.36883852,
#        -77.34203785, -77.40233935, -77.37051356, -77.4760412 ,
#        -77.49446666, -77.41406465, -82.10107996, -82.12453054,
#        -81.96205148, -82.02402803, -81.99722736, -82.05752887,
#        -82.02570307, -82.13123071, -82.14965617, -82.06925416,
#        -79.72028925, -79.74373983, -79.58126077, -79.64323732,
#        -79.61643665, -79.67673816, -79.64491236, -79.75044   ,
#        -79.76886546, -79.68846345, -79.09940912, -79.12285971,
#        -78.96038064, -79.02235719, -78.99555652, -79.05585803,
#        -79.02403223, -79.12955987, -79.14798533, -79.06758332,
#        -85.7925625 , -85.81601309, -85.65353403, -85.71551057,
#        -85.6887099 , -85.74901141, -85.71718562, -85.82271325,
#        -85.84113872, -85.76073671, -98.09050562, -98.1139562 ,
#        -97.95147714, -98.01345369, -97.98665302, -98.04695453,
#        -98.01512873, -98.12065637, -98.13908183, -98.05867982,
#        -90.52081873, -90.54426931, -90.38179025, -90.4437668 ,
#        -90.41696613, -90.47726764, -90.44544184, -90.55096948,
#        -90.56939494, -90.48899293, -80.05949976, -80.08295034,
#        -79.92047128, -79.98244783, -79.95564716, -80.01594867,
#        -79.98412287, -80.08965051, -80.10807597, -80.02767396,
#        -76.97579767, -76.99924826, -76.83676919, -76.89874574,
#        -76.87194507, -76.93224658, -76.90042078, -77.00594842,
#        -77.02437388, -76.94397187, -75.84797479, -75.87142538,
#        -75.70894632, -75.77092287, -75.7441222 , -75.8044237 ,
#        -75.77259791, -75.87812555, -75.89655101, -75.816149  ])

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 478ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 103.577
# 2022-03-20: número de casos reales 30, número de casos predichos 100.71646
# 2022-03-21: número de casos reales 127, número de casos predichos 100.815445
# 2022-03-22: número de casos reales 90, número de casos predichos 100.07724
# 2022-03-23: número de casos reales 106, número de casos predichos 107.89986
# 2022-03-24: número de casos reales 70, número de casos predichos 119.301445
# 2022-03-25: número de casos reales 89, número de casos predichos 113.603424
# 2022-03-26: número de casos reales 26, número de casos predichos 109.34616
# 2022-03-27: número de casos reales 15, número de casos predichos 106.156975
# 2022-03-28: número de casos reales 63, número de casos predichos 99.71131

# %%
tit = 'Red Neuronal Recurrente multivariable con variables atmosféricas para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-59.57700348, -70.71646118,  26.18455505, -10.07723999,
#         -1.89985657, -49.30144501, -24.60342407, -83.34616089,
#        -91.15697479, -36.71131134])

# %%
datos_train = datos_LaPalma_mult_atm.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 2898.0886294163997
# Error absoluto medio (MAE) del modelo: 45.357443237304686
# Raíz del error cuadrático medio (RMSE) del modelo: 53.83389851586452

# %% [markdown]
# # Red Neuronal Recurrente multivariable con todas las variables

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_total_scaled = scaler.fit_transform(datos_LaPalma_mult_total)

# Escalador par alas predicciones y test
scaler_preds = MinMaxScaler(feature_range=(0, 1))
datos_LaPalma_mult_total_scaled_obj = scaler_preds.fit_transform(np.array(datos_LaPalma_mult_total[objetivo]).reshape(-1, 1))

# %%
n_train = len(datos_LaPalma_mult_total_scaled) - dias_prediccion


train = datos_LaPalma_mult_total_scaled[0:n_train, :]

# Para obtener el conjunto de test obtenemos los 10 días anteriores a test para poder conformar el problema supervisado
test = datos_LaPalma_mult_total_scaled[n_train - dias_prediccion:len(datos_LaPalma_mult_total_scaled), :]

# %%
X_train, y_train = get_X_y(train, dias_prediccion)
X_test, y_test = get_X_y(test, dias_prediccion)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# %%
modelo, historico = obtener_modelo_red_neuronal(X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/40
# 14/14 - 3s - loss: 0.0293 - val_loss: 0.0214 - 3s/epoch - 209ms/step
# Epoch 2/40
# 14/14 - 0s - loss: 0.0252 - val_loss: 0.0203 - 165ms/epoch - 12ms/step
# Epoch 3/40
# 14/14 - 0s - loss: 0.0239 - val_loss: 0.0220 - 160ms/epoch - 11ms/step
# Epoch 4/40
# 14/14 - 0s - loss: 0.0216 - val_loss: 0.0229 - 162ms/epoch - 12ms/step
# Epoch 5/40
# 14/14 - 0s - loss: 0.0200 - val_loss: 0.0199 - 160ms/epoch - 11ms/step
# Epoch 6/40
# 14/14 - 0s - loss: 0.0183 - val_loss: 0.0203 - 159ms/epoch - 11ms/step
# Epoch 7/40
# 14/14 - 0s - loss: 0.0170 - val_loss: 0.0249 - 159ms/epoch - 11ms/step
# Epoch 8/40
# 14/14 - 0s - loss: 0.0161 - val_loss: 0.0220 - 161ms/epoch - 12ms/step
# Epoch 9/40
# 14/14 - 0s - loss: 0.0156 - val_loss: 0.0150 - 161ms/epoch - 11ms/step
# Epoch 10/40
# 14/14 - 0s - loss: 0.0142 - val_loss: 0.0186 - 159ms/epoch - 11ms/step
# Epoch 11/40
# 14/14 - 0s - loss: 0.0137 - val_loss: 0.0140 - 160ms/epoch - 11ms/step
# Epoch 12/40
# 14/14 - 0s - loss: 0.0124 - val_loss: 0.0175 - 163ms/epoch - 12ms/step
# Epoch 13/40
# 14/14 - 0s - loss: 0.0112 - val_loss: 0.0233 - 159ms/epoch - 11ms/step
# Epoch 14/40
# 14/14 - 0s - loss: 0.0119 - val_loss: 0.0114 - 160ms/epoch - 11ms/step
# Epoch 15/40
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0126 - 163ms/epoch - 12ms/step
# Epoch 16/40
# 14/14 - 0s - loss: 0.0102 - val_loss: 0.0111 - 161ms/epoch - 12ms/step
# Epoch 17/40
# 14/14 - 0s - loss: 0.0096 - val_loss: 0.0093 - 159ms/epoch - 11ms/step
# Epoch 18/40
# 14/14 - 0s - loss: 0.0090 - val_loss: 0.0134 - 160ms/epoch - 11ms/step
# Epoch 19/40
# 14/14 - 0s - loss: 0.0085 - val_loss: 0.0203 - 160ms/epoch - 11ms/step
# Epoch 20/40
# 14/14 - 0s - loss: 0.0081 - val_loss: 0.0156 - 160ms/epoch - 11ms/step
# Epoch 21/40
# 14/14 - 0s - loss: 0.0078 - val_loss: 0.0144 - 160ms/epoch - 11ms/step
# Epoch 22/40
# 14/14 - 0s - loss: 0.0067 - val_loss: 0.0082 - 158ms/epoch - 11ms/step
# Epoch 23/40
# 14/14 - 0s - loss: 0.0072 - val_loss: 0.0176 - 158ms/epoch - 11ms/step
# Epoch 24/40
# 14/14 - 0s - loss: 0.0074 - val_loss: 0.0081 - 160ms/epoch - 11ms/step
# Epoch 25/40
# 14/14 - 0s - loss: 0.0063 - val_loss: 0.0147 - 159ms/epoch - 11ms/step
# Epoch 26/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0109 - 158ms/epoch - 11ms/step
# Epoch 27/40
# 14/14 - 0s - loss: 0.0071 - val_loss: 0.0090 - 158ms/epoch - 11ms/step
# Epoch 28/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0062 - 161ms/epoch - 11ms/step
# Epoch 29/40
# 14/14 - 0s - loss: 0.0063 - val_loss: 0.0060 - 158ms/epoch - 11ms/step
# Epoch 30/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0086 - 159ms/epoch - 11ms/step
# Epoch 31/40
# 14/14 - 0s - loss: 0.0058 - val_loss: 0.0191 - 159ms/epoch - 11ms/step
# Epoch 32/40
# 14/14 - 0s - loss: 0.0057 - val_loss: 0.0075 - 161ms/epoch - 11ms/step
# Epoch 33/40
# 14/14 - 0s - loss: 0.0059 - val_loss: 0.0062 - 165ms/epoch - 12ms/step
# Epoch 34/40
# 14/14 - 0s - loss: 0.0051 - val_loss: 0.0047 - 160ms/epoch - 11ms/step
# Epoch 35/40
# 14/14 - 0s - loss: 0.0060 - val_loss: 0.0181 - 159ms/epoch - 11ms/step
# Epoch 36/40
# 14/14 - 0s - loss: 0.0058 - val_loss: 0.0061 - 158ms/epoch - 11ms/step
# Epoch 37/40
# 14/14 - 0s - loss: 0.0062 - val_loss: 0.0106 - 159ms/epoch - 11ms/step
# Epoch 38/40
# 14/14 - 0s - loss: 0.0053 - val_loss: 0.0058 - 157ms/epoch - 11ms/step
# Epoch 39/40
# 14/14 - 0s - loss: 0.0056 - val_loss: 0.0109 - 157ms/epoch - 11ms/step
# Epoch 40/40
# 14/14 - 0s - loss: 0.0057 - val_loss: 0.0072 - 157ms/epoch - 11ms/step

# %%
visualizar_perdida(historico)

# %%
test_pred = modelo.predict(X_test)
y_pred = scaler_preds.inverse_transform(test_pred)
y_test = scaler_preds.inverse_transform(y_test.reshape(-1,1))
# Out:
# 1/1 [==============================] - 0s 288ms/step

# %%
visualizar_resultados_texto(y_test, y_pred, fechas)
# Out:
# 2022-03-19: número de casos reales 44, número de casos predichos 93.413605
# 2022-03-20: número de casos reales 30, número de casos predichos 98.40753
# 2022-03-21: número de casos reales 127, número de casos predichos 92.569695
# 2022-03-22: número de casos reales 90, número de casos predichos 89.111885
# 2022-03-23: número de casos reales 106, número de casos predichos 97.80573
# 2022-03-24: número de casos reales 70, número de casos predichos 114.61311
# 2022-03-25: número de casos reales 89, número de casos predichos 108.77657
# 2022-03-26: número de casos reales 26, número de casos predichos 98.45586
# 2022-03-27: número de casos reales 15, número de casos predichos 95.321655
# 2022-03-28: número de casos reales 63, número de casos predichos 89.99612

# %%
tit = 'Red Neuronal Recurrente multivariable con todas las variables para la isla de ' + isla

visualizar_pred_test(y_test, y_pred, fechas, tit)

# %%
dif = y_test - y_pred
dif = dif.flatten()
dif
# Out:
# array([-49.41360474, -68.40753174,  34.43030548,   0.88811493,
#          8.19426727, -44.6131134 , -19.77657318, -72.45585632,
#        -80.32165527, -26.99611664])

# %%
datos_train = datos_LaPalma_mult_total.iloc[:n_train, :]
visualizar_historico(datos_train,y_test,y_pred,objetivo,n_dias_train_vis,fechas,tit,color_isla,dif)

# %%
mae, mse, rmse = obtener_errores(y_test, y_pred)

print("Error cuadrático medio (MSE) del modelo: " + str(mse))
print("Error absoluto medio (MAE) del modelo: " + str(mae))
print("Raíz del error cuadrático medio (RMSE) del modelo: " + str(rmse))
# Out:
# Error cuadrático medio (MSE) del modelo: 2318.632790061069
# Error absoluto medio (MAE) del modelo: 40.549713897705075
# Raíz del error cuadrático medio (RMSE) del modelo: 48.152183647899804
